# %% [markdown]
# <div style="color: #40E0D0; font-family: Cambria, serif; text-align: center; margin: 20px;">
#
# <div style="font-size: 32px; font-weight: bold; margin-bottom: 15px;">UBS AG $4,593,000 Trigger Callable Contingent Yield Notes</div>
#
# <div style="font-size: 24px; font-weight: bold; margin-bottom: 15px;">Linked to the common stock of U.S. Bancorp due August 13, 2026</div>
#
# <div style="font-style: italic; font-size: 16px;">-Valuation report Python notebook by Yadvesh, Krish and Mayank</div>
#
# </div>

# %% [markdown]
# #### Group Members (NetID)
# * Krish Desai (kcdesai2)
# * Mayank Kalra (mkalra2)
# * Yadvesh Yadav (yyada)

# %% [markdown]
# ----

# %% [markdown]
# <div style="border-bottom: 3px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">I) Introduction ==></span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">1) Below are the Key Dates of the Note:</span>
# </div>

# %% [markdown]
# ![](./Images/key_dates.png)

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">2) Below are the Note Offering:</span>
# </div>

# %% [markdown]
# ![](./Images/note_offering.png)

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">3) Below are the Observation Dates and Coupon Payment Dates:</span>
# </div>

# %% [markdown]
# ![](./Images/obs_cpn_dates.png)

# %% [markdown]
# -----

# %% [markdown]
# <div style="border-bottom: 3px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">II) Bloomberg Data (Risk-Free Rates(OIS), Dividend Yield, Volatality Matrix) is as follows ==> </span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">1) Risk Free Rate (OIS Rate):</span>
# </div>

# %% [markdown]
# ![](./Images/usd-ois.png)

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">2) Dividend Yield:</span>
# </div>

# %% [markdown]
# ![](./Images/div.png)

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">3) Implied Volatality Matrix:</span>
# </div>

# %% [markdown]
# ![](./Images/vols.png)

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">III) Getting the Risk-free rates from discount factors above ==></span>
# </div>

# %%
# Importing Necessary Libraries
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# function to get fractional difference between two dates
def get_year_fraction(start_date, end_date):
    if isinstance(start_date, str):
        start_date = datetime.strptime(start_date, "%Y-%m-%d")
    if isinstance(end_date, str):
        end_date = datetime.strptime(end_date, "%Y-%m-%d")
    
    days_diff = (end_date - start_date).days
    
    year_frac = days_diff / 365
    
    return year_frac

# %%
# Key dates
T_0 = "2024-08-08"
T_1 = "2024-08-13"
T_2 = "2026-08-10"
T_3 = "2026-08-13"

# Discount Factors at Key Dates
DF_0 = 1
DF_2 = 0.928096

# DF_1 and DF_3 needs to be calculated using Interpolation
# We have:
dt_2024_08_15 = "2024-08-15"
DF_2024_08_15 = 0.998968
dt_2027_08_09 = "2027-08-09"
DF_2027_08_09 = 0.900124

# Now using Interpolation we have:
DF_1 = DF_0 + (DF_2024_08_15 - DF_0)*(get_year_fraction(T_1, T_0))/(get_year_fraction(dt_2024_08_15, T_0))
print(f"The Value of DF_1 is: {DF_1:.6f}\n")
DF_3 = DF_2 + (DF_2027_08_09 - DF_2)*(get_year_fraction(T_3, T_2))/(get_year_fraction(dt_2027_08_09, T_2))
print(f"The Value of DF_3 is: {DF_3:.6f}")
# Out:
# The Value of DF_1 is: 0.999263
#
# The Value of DF_3 is: 0.927865

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block; margin-bottom: 20px;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">The Discount Factor Table after Linear Interpolation Looks like this</span>
# </div>
#
# <div style="font-family: Cambria, serif;">
#
# | Keys | Dates     | DF        |
# |------|-----------|-----------|
# | T_0  | 8/8/2024  | 1.000000  |
# | T_1  | 8/13/2024 | 0.999263  |
# | T_2  | 8/10/2026 | 0.928096  |
# | T_3  | 8/13/2026 | 0.927865  |
#
# </div>

# %%
# function to get r(0,T) from the discount factors DF
def r_from_DF(DF, T, T_0):
    dt = get_year_fraction(T_0, T)
    r = -np.log(DF)/dt
    return r, dt

# %%
r_T0_T1, T0_T1 = r_from_DF(DF_1, T_1, T_0)
print(f"The Value of continuously compounded risk free rate between T_0 and T_1(r_T0_T1) is: {r_T0_T1:.8f}\n")
r_T0_T2, T0_T2 = r_from_DF(DF_2, T_2, T_0)
print(f"The Value of continuously compounded risk free rate between T_0 and T_2(r_T0_T2) is: {r_T0_T2:.8f}\n")
r_T0_T3, T0_T3 = r_from_DF(DF_3, T_3, T_0)
print(f"The Value of continuously compounded risk free rate between T_0 and T_3(r_T0_T3) is: {r_T0_T3:.8f}\n")
# Out:
# The Value of continuously compounded risk free rate between T_0 and T_1(r_T0_T1) is: 0.05383127
#
# The Value of continuously compounded risk free rate between T_0 and T_2(r_T0_T2) is: 0.03720811
#
# The Value of continuously compounded risk free rate between T_0 and T_3(r_T0_T3) is: 0.03717961

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block; margin-bottom: 20px;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">The Discount Factor Table after Linear Interpolation Looks like this</span>
# </div>
#
# <div style="font-family: Cambria, serif;">
#
# | Keys | Dates     | DF        | delta(T_x, T_0) | r(0,T_x)   |
# |------|-----------|-----------|-----------------|------------|
# | T_0  | 8/8/2024  | 1.000000  | 0.00000000     | 0.00000000 |
# | T_1  | 8/13/2024 | 0.999263  | 0.01369863     | 0.05383127 |
# | T_2  | 8/10/2026 | 0.928096  | 2.00547945     | <span style="background-color: green;">0.03720811</span> |
# | T_3  | 8/13/2026 | 0.927865  | 2.01369863     | 0.03717961 |
#
# </div>

# %%
# Now we need to calculate teh forward rate F(T_1,T_3)
T1_T3 = get_year_fraction(T_1, T_3)
F_T1_T3 = ((r_T0_T3*T0_T3) - (r_T0_T1*T0_T1))/T1_T3
print(f"The Value of continuously compounded Forward rate between T_1 and T_3(F_T1_T3) is: {F_T1_T3:.8f}\n")
# Out:
# The Value of continuously compounded Forward rate between T_1 and T_3(F_T1_T3) is: 0.03706556

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block; margin-bottom: 20px;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">1) The Discount Factor Table after Linear Interpolation Looks like this:</span>
# </div>
#
# <div style="font-family: Cambria, serif;">
#
# | Keys | Dates     | DF        | delta(T_x, T_0) | r(0,T_x)   | F(T_x1,T_x2)   |
# |------|-----------|-----------|-----------------|------------|------------|
# | T_0  | 8/8/2024  | 1.000000  | 0.00000000     | 0.00000000 | -  |
# | T_1  | 8/13/2024 | 0.999263  | 0.01369863     | 0.05383127 | -  |
# | T_2  | 8/10/2026 | 0.928096  | 2.00547945     | <span style="background-color: green;">0.03720811</span> | -  |
# | T_3  | 8/13/2026 | 0.927865  | 2.01369863     | 0.03717961 | <span style="background-color: green;">0.03706556</span> |
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">2) The continuous dividend yield 'D' from bloomberg data is 4.842% or 0.04842</span>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block; margin-bottom: 20px;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 20px;">2) The Moneyness and Volatility Matrix Looks like this:</span>
# </div>
#
# <div style="font-family: Cambria, serif;">
#
# | Moneyness | Implied Volatility (24M) |
# |-----------|------------------|
# | 60.00     | 37.779%         |
# | 65.00     | 36.529%         |
# | 70.00     | 34.846%         |
# | 75.00     | 33.187%         |
# | 80.00     | 31.841%         |
# | 85.00     | 30.770%         |
# | 90.00     | 29.896%         |
# | 95.00     | 29.334%         |
# | 100.00    | 28.662%         |
# | 105.00    | 28.035%         |
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">IV) Now Calculating the Value of the Note using Binomial Trees ==></span>
# </div>

# %%
# note features that will go in the functions to callculate teh value of the note

# initial stock price ($)
S0 = 41.76

# coupon barrier and downside threshold ($)
B = 0.6*S0

# contingent coupon per observation date ($)
coupon_payment = 25.625

# principal amount per note ($)
principal = 1000

# share delivery coefficient if below downside threshold at maturity
share_delivery_amount = 23.9464

# continously compounded risk-free rate(T_0 to T_2) for p calculation
r1 = r_T0_T2

# continously compounded forward rate(T_1 to T_3) for discounting
r2 = F_T1_T3

# continuous dividend yield
D = 0.04842

# implied volatility at 80 Moneyness
sigma = 0.31841

# number of time steps
N = 1000

# fractional time between T_0 and T_2 for p calculation
T0_T2

# fractional time between T_1 and T_3 for discounting
T1_T3
# Out:
# 2.0

# %%
sigma_moneyness = {
    60.00: 0.37779,
    65.00: 0.36529,
    70.00: 0.34846,
    75.00: 0.33187,
    80.00: 0.31841,
    85.00: 0.30770,
    90.00: 0.29896,
    95.00: 0.29334,
    100.00: 0.28662,
    105.00: 0.28035
}

# %% [markdown]
# ### We will calculate Note Value using the following binomial lattice methods.
# * Cox, Ross and Rubinstein, 1979, CRR ==> ($u = e^{\sigma\Delta t}, d = 1/u$)
# * Rendleman and Bartter, 1979, RB ==> ($u = \exp((r-\delta-0.5\sigma^2)\Delta t+\sigma\sqrt{\Delta t}), d = \exp((r-\delta-0.5\sigma^2)\Delta t-\sigma\sqrt{\Delta t})$)
# * Leisen and Reimer, 1996 (see Lecture 5 notes), LR ==>
#   - $q = h(d_2)$
#   - $u = e^{(r-\delta)\Delta t}\frac{q*}{q}$
#   - $d = \frac{e^{(r-\delta)\Delta t} - qu}{1 - q}$
#
#
# Where:
#
# $d_{1,2} = \frac{\ln(S/K) + (r - \delta \pm \frac{1}{2}\sigma^2)(T)}{\sigma\sqrt{(T)}}$
#
# $h(x) = \frac{1}{2} + sign(x)\sqrt{\frac{1}{4} - \frac{1}{4}\exp\left\{-\left(\frac{x}{N+\frac{1}{3}}\right)^2\left(N+\frac{1}{6}\right)\right\}}$
#
# $q* = h(d_1)$

# %%
# defining h(x) function for Leisen-Reimer model
def h(x, N):
    func_value = 0.5 + np.sign(x) * np.sqrt(0.25 - 0.25 * np.exp(-((x / (N + 1/3)) ** 2) * (N + 1/6)))
    return func_value

# %%
# function to build the stock tree
def Stock_tree(N, S0, B, sigma, r1, D, T0_T2, model):

    S = np.zeros([N+1, N+1])
    dt02 = T0_T2/N

    # choice of model
    if model == 'CRR':
        u = np.exp(sigma*np.sqrt(dt02))
        d = np.exp(-sigma*np.sqrt(dt02))
        p = (np.exp((r1-D)*dt02)-d)/(u-d)

    elif model == 'RB':
        u = np.exp((r1 - D - 0.5*sigma**2)*dt02 + sigma*np.sqrt(dt02))
        d = np.exp((r1 - D - 0.5*sigma**2)*dt02 - sigma*np.sqrt(dt02))
        p = (np.exp((r1-D)*dt02)-d)/(u-d)

    elif model == 'LR':
        d1 = (np.log(S0/B) + (r1 - D + 0.5*sigma**2)*T0_T2)/(sigma*np.sqrt(T0_T2))
        d2 = d1 - sigma*np.sqrt(T0_T2)
        q1 = h(d2, N)
        q2 = h(d1, N)
        u = np.exp((r1 - D) * dt02) * (q2 / q1)
        d = (np.exp((r1 - D) * dt02) - q1 * u) / (1 - q1)
        p = q1

    # setting S0 as initial stock price
    S[0, 0] = S0

    # building the stock tree
    for i in range(1, N + 1):
        S[i,0] = S[i-1,0] * d
        for j in range(1,i+1):
            S[i,j] = S[i-1,j-1] * u

    return S, p, u, d, model

# %%
# function to calculate the value of the note
def Note_Value(S, p, N, sigma, T0_T2, T1_T3, r2, model):

    dt02 = T0_T2/N
    dt13 = T1_T3/N

    # getting the call start step after which the note becomes callable (6 months)
    # call start date  after 6 months from "2024-08-08" is "2025-02-08"
    call_start_date = "2025-02-08"
    call_start_time = get_year_fraction(T_0, call_start_date)      
    call_start_step = int(call_start_time/dt02)

    # coupon dates stored as list to be used in function to give out coupon payments at these dates if stock is greater than coupon barrier
    observation_dates = [
        '2024-11-08',
        '2025-02-10',
        '2025-05-08',
        '2025-08-08',
        '2025-11-10',
        '2026-02-09',
        '2026-05-08'
    ]

    # calculating observation times (year fractions from T_0)
    observation_times = [get_year_fraction(T_0, date) for date in observation_dates]

    # calculate observation steps (the steps at which observation dates occur)
    observation_steps = [int(time / dt02) for time in observation_times]

    value_tree = np.zeros_like(S)

    # determine Payoffs at Maturity
    for j in range(N+1):
        S_T = S[N, j]
        if S_T >= B:
            # receive principal back plus coupon if above barrier
            value_tree[N, j] = principal + coupon_payment
        else:
            # receive share delivery amount times stock price
            value_tree[N, j] = share_delivery_amount*S_T

    # applying backward Induction
    for i in range(N-1, -1, -1):
        for j in range(i + 1):
            S_t = S[i, j]

            # calculating expected continuation value
            continuation_value = np.exp(-r2 * dt13)*(p*value_tree[i+1, j+1] + (1-p)*value_tree[i+1, j])

            # add contingent coupon if barrier is breached
            if i in observation_steps and S_t >= B:
                continuation_value = continuation_value + coupon_payment

            elif i in observation_steps:
                continuation_value = continuation_value

            # check if issuer will call the note
            if i in observation_steps and i >= call_start_step:
                # calculate call payoff
                call_payoff = principal + coupon_payment

                # issuer will call if continuation value is larger than call_payoff
                node_value = min(call_payoff, continuation_value)

            else:
                node_value = continuation_value

            value_tree[i, j] = node_value

    # discounting back to the note's present value
    note_value = value_tree[0, 0]

    moneyness = next(k for k, v in sigma_moneyness.items() if v == sigma)
    print(f"The estimated fair value of the note at moneyness of {moneyness} for {N} time steps and {model} model is: ${note_value:.4f}")
    return note_value

# %%
# build the stock tree for N=1000 time steps CRR model
S, p, u, d, model = Stock_tree(N, S0, B, sigma, r1, D, T0_T2, model="CRR")

# %%
# calculate the value of the note for N=1000 time steps CRR model
note_value = Note_Value(S, p, N, sigma, T0_T2, T1_T3, r2, model)
# Out:
# The estimated fair value of the note at moneyness of 80.0 for 1000 time steps and CRR model is: $976.1561

# %%
# build the stock tree for N=1000 time steps RB model
S, p, u, d, model = Stock_tree(N, S0, B, sigma, r1, D, T0_T2, model="RB")

# %%
# calculate the value of the note for N=1000 time steps RB model
note_value = Note_Value(S, p, N, sigma, T0_T2, T1_T3, r2, model)
# Out:
# The estimated fair value of the note at moneyness of 80.0 for 1000 time steps and RB model is: $977.9710

# %%
# build the stock tree for N=1000 time steps LR model
S, p, u, d, model = Stock_tree(N, S0, B, sigma, r1, D, T0_T2, model="LR")

# %%
# calculate the value of the note for N=1000 time steps LR model
note_value = Note_Value(S, p, N, sigma, T0_T2, T1_T3, r2, model)
# Out:
# The estimated fair value of the note at moneyness of 80.0 for 1000 time steps and LR model is: $980.4148

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">V) Sensitivity Analysis w.r.t to different Moneyness(different implied volatility) for 'CRR' model ==></span>
# </div>

# %%
N = 9999

# %%
sig = [0.37779, 0.36529, 0.34846, 0.33187, 0.31841, 0.30770, 0.29896, 0.29334, 0.28662]

# %%
l_CRR = []
for i in sig:
    S, p, u, d, model = Stock_tree(N, S0, B, i, r1, D, T0_T2, model="CRR")
    note_value = Note_Value(S, p, N, i, T0_T2, T1_T3, r2, model)
    l_CRR.append(note_value)
# Out:
# The estimated fair value of the note at moneyness of 60.0 for 9999 time steps and CRR model is: $941.5477
# The estimated fair value of the note at moneyness of 65.0 for 9999 time steps and CRR model is: $948.3446
# The estimated fair value of the note at moneyness of 70.0 for 9999 time steps and CRR model is: $960.3284
# The estimated fair value of the note at moneyness of 75.0 for 9999 time steps and CRR model is: $969.5891
# The estimated fair value of the note at moneyness of 80.0 for 9999 time steps and CRR model is: $978.8840
# The estimated fair value of the note at moneyness of 85.0 for 9999 time steps and CRR model is: $985.1034
# The estimated fair value of the note at moneyness of 90.0 for 9999 time steps and CRR model is: $988.9398
# The estimated fair value of the note at moneyness of 95.0 for 9999 time steps and CRR model is: $991.7623
# The estimated fair value of the note at moneyness of 100.0 for 9999 time steps and CRR model is: $996.0410

# %%
avg_CRR = np.mean(l_CRR)
print(f"The estimated average value of the note for {N} time steps and {model} model is: ${avg_CRR:.4f}")
# Out:
# The estimated average value of the note for 9999 time steps and CRR model is: $973.3934

# %%
money_ness = range(60, 105, 5)
df_l_crr = pd.DataFrame({
    'Moneyness': money_ness,
    'Note_Value': l_CRR
})

df_l_crr = df_l_crr.reset_index(drop=True)
df_l_crr.head()
# Out:
#    Moneyness  Note_Value
# 0         60  941.547689
# 1         65  948.344569
# 2         70  960.328396
# 3         75  969.589121
# 4         80  978.884032

# %%
plt.figure(figsize=(20, 10))
plt.plot(df_l_crr['Moneyness'],df_l_crr['Note_Value'],'o-', markersize=5, label='Cox, Ross and Rubinstein (1979)')
plt.xlabel('Moneyness')
plt.ylabel('CRR Note Value')
plt.title('CRR Note Value vs. Moneyness')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">VI) Sensitivity Analysis w.r.t to different Moneyness(different implied volatility) for 'RB' model ==></span>
# </div>

# %%
l_RB = []
for i in sig:
    S, p, u, d, model = Stock_tree(N, S0, B, i, r1, D, T0_T2, model="RB")
    note_value = Note_Value(S, p, N, i, T0_T2, T1_T3, r2, model)
    l_RB.append(note_value)
# Out:
# The estimated fair value of the note at moneyness of 60.0 for 9999 time steps and RB model is: $940.5464
# The estimated fair value of the note at moneyness of 65.0 for 9999 time steps and RB model is: $948.8116
# The estimated fair value of the note at moneyness of 70.0 for 9999 time steps and RB model is: $959.6604
# The estimated fair value of the note at moneyness of 75.0 for 9999 time steps and RB model is: $969.7969
# The estimated fair value of the note at moneyness of 80.0 for 9999 time steps and RB model is: $978.5521
# The estimated fair value of the note at moneyness of 85.0 for 9999 time steps and RB model is: $984.3070
# The estimated fair value of the note at moneyness of 90.0 for 9999 time steps and RB model is: $989.2559
# The estimated fair value of the note at moneyness of 95.0 for 9999 time steps and RB model is: $992.0137
# The estimated fair value of the note at moneyness of 100.0 for 9999 time steps and RB model is: $995.9878

# %%
avg_RB = np.mean(l_RB)
print(f"The estimated average value of the note for {N} time steps and {model} model is: ${avg_RB:.4f}")
# Out:
# The estimated average value of the note for 9999 time steps and RB model is: $973.2146

# %%
df_l_rb = pd.DataFrame({
    'Moneyness': money_ness,
    'Note_Value': l_RB
})

df_l_rb = df_l_rb.reset_index(drop=True)
df_l_rb.head()
# Out:
#    Moneyness  Note_Value
# 0         60  940.546419
# 1         65  948.811552
# 2         70  959.660366
# 3         75  969.796906
# 4         80  978.552130

# %%
plt.figure(figsize=(20, 10))
plt.plot(df_l_rb['Moneyness'],df_l_rb['Note_Value'],'o-', markersize=5, label='Rendleman and Bartter (1979)')
plt.xlabel('Moneyness')
plt.ylabel('RB Note Value')
plt.title('RB Note Value vs. Moneyness')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">VII) Sensitivity Analysis w.r.t to different Moneyness(different implied volatility) for 'LR' model ==></span>
# </div>

# %%
l_LR = []
for i in sig:
    S, p, u, d, model = Stock_tree(N, S0, B, i, r1, D, T0_T2, model="LR")
    note_value = Note_Value(S, p, N, i, T0_T2, T1_T3, r2, model)
    l_LR.append(note_value)
# Out:
# The estimated fair value of the note at moneyness of 60.0 for 9999 time steps and LR model is: $941.0421
# The estimated fair value of the note at moneyness of 65.0 for 9999 time steps and LR model is: $949.1577
# The estimated fair value of the note at moneyness of 70.0 for 9999 time steps and LR model is: $959.7510
# The estimated fair value of the note at moneyness of 75.0 for 9999 time steps and LR model is: $970.0834
# The estimated fair value of the note at moneyness of 80.0 for 9999 time steps and LR model is: $978.3499
# The estimated fair value of the note at moneyness of 85.0 for 9999 time steps and LR model is: $984.4764
# The estimated fair value of the note at moneyness of 90.0 for 9999 time steps and LR model is: $989.4747
# The estimated fair value of the note at moneyness of 95.0 for 9999 time steps and LR model is: $992.4789
# The estimated fair value of the note at moneyness of 100.0 for 9999 time steps and LR model is: $995.9951

# %%
avg_LR = np.mean(l_LR)
print(f"The estimated average value of the note for {N} time steps and {model} model is: ${avg_LR:.4f}")
# Out:
# The estimated average value of the note for 9999 time steps and LR model is: $973.4233

# %%
df_l_lr = pd.DataFrame({
    'Moneyness': money_ness,
    'Note_Value': l_LR
})

df_l_lr = df_l_lr.reset_index(drop=True)
df_l_lr.head()
# Out:
#    Moneyness  Note_Value
# 0         60  941.042131
# 1         65  949.157662
# 2         70  959.751039
# 3         75  970.083393
# 4         80  978.349904

# %%
plt.figure(figsize=(20, 10))
plt.plot(df_l_lr['Moneyness'],df_l_lr['Note_Value'],'o-', markersize=5, label='Leisen and Reimer (1996)')
plt.xlabel('Moneyness')
plt.ylabel('LR Note Value')
plt.title('LR Note Value vs. Moneyness')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">VIII) Increasing the Number of Steps from 50 till 1000 and plotting the value graph for 80 Moneyness 'CRR' Model==></span>
# </div>

# %%
N_values = range(50, 1000, 3)
CRR_values = []

for i in N_values:
    S, p, u, d, model = Stock_tree(i, S0, B, sigma, r1, D, T0_T2, model="CRR")
    note_value = Note_Value(S, p, i, sigma, T0_T2, T1_T3, r2, model)
    CRR_values.append(note_value)
# Out:
# The estimated fair value of the note at moneyness of 80.0 for 50 time steps and CRR model is: $991.0136
# The estimated fair value of the note at moneyness of 80.0 for 53 time steps and CRR model is: $977.3653
# The estimated fair value of the note at moneyness of 80.0 for 56 time steps and CRR model is: $984.3629
# The estimated fair value of the note at moneyness of 80.0 for 59 time steps and CRR model is: $972.0450
# The estimated fair value of the note at moneyness of 80.0 for 62 time steps and CRR model is: $979.5736
# The estimated fair value of the note at moneyness of 80.0 for 65 time steps and CRR model is: $986.3261
# The estimated fair value of the note at moneyness of 80.0 for 68 time steps and CRR model is: $977.1252
# The estimated fair value of the note at moneyness of 80.0 for 71 time steps and CRR model is: $982.3546
# The estimated fair value of the note at moneyness of 80.0 for 74 time steps and CRR model is: $971.3617
# The estimated fair value of the note at moneyness of 80.0 for 77 time steps and CRR model is: $977.7773
# The estimated fair value of the note at moneyness of 80.0 for 80 time steps and CRR model is: $986.6569
# The estimated fair value of the note at moneyness of 80.0 for 83 time steps and CRR model is: $977.0894
# The estimated fair value of the note at moneyness of 80.0 for 86 time steps and CRR model is: $983.8713
# The estimated fair value of the note at moneyness of 80.0 for 89 time steps and CRR model is: $972.7209
# The estimated fair value of the note at moneyness of 80.0 for 92 time steps and CRR model is: $978.0518
# The estimated fair value of the note at moneyness of 80.0 for 95 time steps and CRR model is: $987.2551
# The estimated fair value of the note at moneyness of 80.0 for 98 time steps and CRR model is: $978.3914
# The estimated fair value of the note at moneyness of 80.0 for 101 time steps and CRR model is: $983.9800
# The estimated fair value of the note at moneyness of 80.0 for 104 time steps and CRR model is: $974.2939
# The estimated fair value of the note at moneyness of 80.0 for 107 time steps and CRR model is: $980.8617
# The estimated fair value of the note at moneyness of 80.0 for 110 time steps and CRR model is: $971.2598
# The estimated fair value of the note at moneyness of 80.0 for 113 time steps and CRR model is: $980.6960
# The estimated fair value of the note at moneyness of 80.0 for 116 time steps and CRR model is: $984.0726
# The estimated fair value of the note at moneyness of 80.0 for 119 time steps and CRR model is: $976.1576
# The estimated fair value of the note at moneyness of 80.0 for 122 time steps and CRR model is: $982.4870
# The estimated fair value of the note at moneyness of 80.0 for 125 time steps and CRR model is: $974.3678
# The estimated fair value of the note at moneyness of 80.0 for 128 time steps and CRR model is: $979.0163
# The estimated fair value of the note at moneyness of 80.0 for 131 time steps and CRR model is: $971.5196
# The estimated fair value of the note at moneyness of 80.0 for 134 time steps and CRR model is: $977.8467
# The estimated fair value of the note at moneyness of 80.0 for 137 time steps and CRR model is: $983.7937
# The estimated fair value of the note at moneyness of 80.0 for 140 time steps and CRR model is: $976.4985
# The estimated fair value of the note at moneyness of 80.0 for 143 time steps and CRR model is: $981.6577
# The estimated fair value of the note at moneyness of 80.0 for 146 time steps and CRR model is: $974.0589
# The estimated fair value of the note at moneyness of 80.0 for 149 time steps and CRR model is: $979.8430
# The estimated fair value of the note at moneyness of 80.0 for 152 time steps and CRR model is: $971.4019
# The estimated fair value of the note at moneyness of 80.0 for 155 time steps and CRR model is: $978.0052
# The estimated fair value of the note at moneyness of 80.0 for 158 time steps and CRR model is: $983.5958
# The estimated fair value of the note at moneyness of 80.0 for 161 time steps and CRR model is: $977.7962
# The estimated fair value of the note at moneyness of 80.0 for 164 time steps and CRR model is: $981.2079
# The estimated fair value of the note at moneyness of 80.0 for 167 time steps and CRR model is: $974.3483
# The estimated fair value of the note at moneyness of 80.0 for 170 time steps and CRR model is: $979.3870
# The estimated fair value of the note at moneyness of 80.0 for 173 time steps and CRR model is: $973.1319
# The estimated fair value of the note at moneyness of 80.0 for 176 time steps and CRR model is: $979.4239
# The estimated fair value of the note at moneyness of 80.0 for 179 time steps and CRR model is: $983.2801
# The estimated fair value of the note at moneyness of 80.0 for 182 time steps and CRR model is: $976.7370
# The estimated fair value of the note at moneyness of 80.0 for 185 time steps and CRR model is: $981.5874
# The estimated fair value of the note at moneyness of 80.0 for 188 time steps and CRR model is: $976.3272
# The estimated fair value of the note at moneyness of 80.0 for 191 time steps and CRR model is: $980.4570
# The estimated fair value of the note at moneyness of 80.0 for 194 time steps and CRR model is: $973.9974
# The estimated fair value of the note at moneyness of 80.0 for 197 time steps and CRR model is: $978.1738
# The estimated fair value of the note at moneyness of 80.0 for 200 time steps and CRR model is: $984.6002
# The estimated fair value of the note at moneyness of 80.0 for 203 time steps and CRR model is: $978.2304
# The estimated fair value of the note at moneyness of 80.0 for 206 time steps and CRR model is: $982.8927
# The estimated fair value of the note at moneyness of 80.0 for 209 time steps and CRR model is: $976.3343
# The estimated fair value of the note at moneyness of 80.0 for 212 time steps and CRR model is: $980.9100
# The estimated fair value of the note at moneyness of 80.0 for 215 time steps and CRR model is: $974.9759
# The estimated fair value of the note at moneyness of 80.0 for 218 time steps and CRR model is: $979.5101
# The estimated fair value of the note at moneyness of 80.0 for 221 time steps and CRR model is: $974.3933
# The estimated fair value of the note at moneyness of 80.0 for 224 time steps and CRR model is: $977.9444
# The estimated fair value of the note at moneyness of 80.0 for 227 time steps and CRR model is: $983.6456
# The estimated fair value of the note at moneyness of 80.0 for 230 time steps and CRR model is: $977.5689
# The estimated fair value of the note at moneyness of 80.0 for 233 time steps and CRR model is: $981.9774
# The estimated fair value of the note at moneyness of 80.0 for 236 time steps and CRR model is: $977.3854
# The estimated fair value of the note at moneyness of 80.0 for 239 time steps and CRR model is: $981.1811
# The estimated fair value of the note at moneyness of 80.0 for 242 time steps and CRR model is: $975.2800
# The estimated fair value of the note at moneyness of 80.0 for 245 time steps and CRR model is: $979.3533
# The estimated fair value of the note at moneyness of 80.0 for 248 time steps and CRR model is: $973.7190
# The estimated fair value of the note at moneyness of 80.0 for 251 time steps and CRR model is: $978.1375
# The estimated fair value of the note at moneyness of 80.0 for 254 time steps and CRR model is: $983.6582
# The estimated fair value of the note at moneyness of 80.0 for 257 time steps and CRR model is: $977.6655
# The estimated fair value of the note at moneyness of 80.0 for 260 time steps and CRR model is: $981.9244
# The estimated fair value of the note at moneyness of 80.0 for 263 time steps and CRR model is: $976.8115
# The estimated fair value of the note at moneyness of 80.0 for 266 time steps and CRR model is: $980.7162
# The estimated fair value of the note at moneyness of 80.0 for 269 time steps and CRR model is: $976.3927
# The estimated fair value of the note at moneyness of 80.0 for 272 time steps and CRR model is: $979.2447
# The estimated fair value of the note at moneyness of 80.0 for 275 time steps and CRR model is: $974.6021
# The estimated fair value of the note at moneyness of 80.0 for 278 time steps and CRR model is: $978.9981
# The estimated fair value of the note at moneyness of 80.0 for 281 time steps and CRR model is: $973.5262
# The estimated fair value of the note at moneyness of 80.0 for 284 time steps and CRR model is: $978.9767
# The estimated fair value of the note at moneyness of 80.0 for 287 time steps and CRR model is: $982.8269
# The estimated fair value of the note at moneyness of 80.0 for 290 time steps and CRR model is: $977.4974
# The estimated fair value of the note at moneyness of 80.0 for 293 time steps and CRR model is: $981.2289
# The estimated fair value of the note at moneyness of 80.0 for 296 time steps and CRR model is: $976.5728
# The estimated fair value of the note at moneyness of 80.0 for 299 time steps and CRR model is: $980.2599
# The estimated fair value of the note at moneyness of 80.0 for 302 time steps and CRR model is: $975.0585
# The estimated fair value of the note at moneyness of 80.0 for 305 time steps and CRR model is: $979.3163
# The estimated fair value of the note at moneyness of 80.0 for 308 time steps and CRR model is: $974.1372
# The estimated fair value of the note at moneyness of 80.0 for 311 time steps and CRR model is: $978.3805
# The estimated fair value of the note at moneyness of 80.0 for 314 time steps and CRR model is: $982.7672
# The estimated fair value of the note at moneyness of 80.0 for 317 time steps and CRR model is: $978.9054
# The estimated fair value of the note at moneyness of 80.0 for 320 time steps and CRR model is: $981.8573
# The estimated fair value of the note at moneyness of 80.0 for 323 time steps and CRR model is: $977.2366
# The estimated fair value of the note at moneyness of 80.0 for 326 time steps and CRR model is: $981.3403
# The estimated fair value of the note at moneyness of 80.0 for 329 time steps and CRR model is: $976.4282
# The estimated fair value of the note at moneyness of 80.0 for 332 time steps and CRR model is: $979.3040
# The estimated fair value of the note at moneyness of 80.0 for 335 time steps and CRR model is: $974.8123
# The estimated fair value of the note at moneyness of 80.0 for 338 time steps and CRR model is: $978.7205
# The estimated fair value of the note at moneyness of 80.0 for 341 time steps and CRR model is: $973.9259
# The estimated fair value of the note at moneyness of 80.0 for 344 time steps and CRR model is: $979.2390
# The estimated fair value of the note at moneyness of 80.0 for 347 time steps and CRR model is: $982.4894
# The estimated fair value of the note at moneyness of 80.0 for 350 time steps and CRR model is: $977.9929
# The estimated fair value of the note at moneyness of 80.0 for 353 time steps and CRR model is: $981.9227
# The estimated fair value of the note at moneyness of 80.0 for 356 time steps and CRR model is: $977.2190
# The estimated fair value of the note at moneyness of 80.0 for 359 time steps and CRR model is: $980.8987
# The estimated fair value of the note at moneyness of 80.0 for 362 time steps and CRR model is: $976.3976
# The estimated fair value of the note at moneyness of 80.0 for 365 time steps and CRR model is: $978.8304
# The estimated fair value of the note at moneyness of 80.0 for 368 time steps and CRR model is: $975.1046
# The estimated fair value of the note at moneyness of 80.0 for 371 time steps and CRR model is: $978.1663
# The estimated fair value of the note at moneyness of 80.0 for 374 time steps and CRR model is: $974.3634
# The estimated fair value of the note at moneyness of 80.0 for 377 time steps and CRR model is: $977.7582
# The estimated fair value of the note at moneyness of 80.0 for 380 time steps and CRR model is: $982.1207
# The estimated fair value of the note at moneyness of 80.0 for 383 time steps and CRR model is: $978.3129
# The estimated fair value of the note at moneyness of 80.0 for 386 time steps and CRR model is: $981.9262
# The estimated fair value of the note at moneyness of 80.0 for 389 time steps and CRR model is: $977.0130
# The estimated fair value of the note at moneyness of 80.0 for 392 time steps and CRR model is: $980.3652
# The estimated fair value of the note at moneyness of 80.0 for 395 time steps and CRR model is: $976.6061
# The estimated fair value of the note at moneyness of 80.0 for 398 time steps and CRR model is: $979.6841
# The estimated fair value of the note at moneyness of 80.0 for 401 time steps and CRR model is: $974.9579
# The estimated fair value of the note at moneyness of 80.0 for 404 time steps and CRR model is: $978.7411
# The estimated fair value of the note at moneyness of 80.0 for 407 time steps and CRR model is: $974.5726
# The estimated fair value of the note at moneyness of 80.0 for 410 time steps and CRR model is: $978.1019
# The estimated fair value of the note at moneyness of 80.0 for 413 time steps and CRR model is: $982.4423
# The estimated fair value of the note at moneyness of 80.0 for 416 time steps and CRR model is: $978.4198
# The estimated fair value of the note at moneyness of 80.0 for 419 time steps and CRR model is: $981.2870
# The estimated fair value of the note at moneyness of 80.0 for 422 time steps and CRR model is: $977.8455
# The estimated fair value of the note at moneyness of 80.0 for 425 time steps and CRR model is: $980.8809
# The estimated fair value of the note at moneyness of 80.0 for 428 time steps and CRR model is: $977.1934
# The estimated fair value of the note at moneyness of 80.0 for 431 time steps and CRR model is: $980.0431
# The estimated fair value of the note at moneyness of 80.0 for 434 time steps and CRR model is: $975.5400
# The estimated fair value of the note at moneyness of 80.0 for 437 time steps and CRR model is: $978.9379
# The estimated fair value of the note at moneyness of 80.0 for 440 time steps and CRR model is: $975.5533
# The estimated fair value of the note at moneyness of 80.0 for 443 time steps and CRR model is: $978.2685
# The estimated fair value of the note at moneyness of 80.0 for 446 time steps and CRR model is: $974.4425
# The estimated fair value of the note at moneyness of 80.0 for 449 time steps and CRR model is: $978.3840
# The estimated fair value of the note at moneyness of 80.0 for 452 time steps and CRR model is: $981.7473
# The estimated fair value of the note at moneyness of 80.0 for 455 time steps and CRR model is: $978.1411
# The estimated fair value of the note at moneyness of 80.0 for 458 time steps and CRR model is: $981.3788
# The estimated fair value of the note at moneyness of 80.0 for 461 time steps and CRR model is: $977.0997
# The estimated fair value of the note at moneyness of 80.0 for 464 time steps and CRR model is: $980.6762
# The estimated fair value of the note at moneyness of 80.0 for 467 time steps and CRR model is: $977.1518
# The estimated fair value of the note at moneyness of 80.0 for 470 time steps and CRR model is: $979.6199
# The estimated fair value of the note at moneyness of 80.0 for 473 time steps and CRR model is: $976.1121
# The estimated fair value of the note at moneyness of 80.0 for 476 time steps and CRR model is: $979.0472
# The estimated fair value of the note at moneyness of 80.0 for 479 time steps and CRR model is: $975.3808
# The estimated fair value of the note at moneyness of 80.0 for 482 time steps and CRR model is: $978.7474
# The estimated fair value of the note at moneyness of 80.0 for 485 time steps and CRR model is: $974.8625
# The estimated fair value of the note at moneyness of 80.0 for 488 time steps and CRR model is: $978.8326
# The estimated fair value of the note at moneyness of 80.0 for 491 time steps and CRR model is: $981.9305
# The estimated fair value of the note at moneyness of 80.0 for 494 time steps and CRR model is: $978.1423
# The estimated fair value of the note at moneyness of 80.0 for 497 time steps and CRR model is: $981.5693
# The estimated fair value of the note at moneyness of 80.0 for 500 time steps and CRR model is: $977.8686
# The estimated fair value of the note at moneyness of 80.0 for 503 time steps and CRR model is: $980.6364
# The estimated fair value of the note at moneyness of 80.0 for 506 time steps and CRR model is: $976.6144
# The estimated fair value of the note at moneyness of 80.0 for 509 time steps and CRR model is: $980.1107
# The estimated fair value of the note at moneyness of 80.0 for 512 time steps and CRR model is: $975.9124
# The estimated fair value of the note at moneyness of 80.0 for 515 time steps and CRR model is: $978.5208
# The estimated fair value of the note at moneyness of 80.0 for 518 time steps and CRR model is: $975.5698
# The estimated fair value of the note at moneyness of 80.0 for 521 time steps and CRR model is: $978.2254
# The estimated fair value of the note at moneyness of 80.0 for 524 time steps and CRR model is: $974.9060
# The estimated fair value of the note at moneyness of 80.0 for 527 time steps and CRR model is: $979.0429
# The estimated fair value of the note at moneyness of 80.0 for 530 time steps and CRR model is: $981.9677
# The estimated fair value of the note at moneyness of 80.0 for 533 time steps and CRR model is: $978.5871
# The estimated fair value of the note at moneyness of 80.0 for 536 time steps and CRR model is: $981.0390
# The estimated fair value of the note at moneyness of 80.0 for 539 time steps and CRR model is: $977.6302
# The estimated fair value of the note at moneyness of 80.0 for 542 time steps and CRR model is: $980.5174
# The estimated fair value of the note at moneyness of 80.0 for 545 time steps and CRR model is: $976.4917
# The estimated fair value of the note at moneyness of 80.0 for 548 time steps and CRR model is: $979.4487
# The estimated fair value of the note at moneyness of 80.0 for 551 time steps and CRR model is: $976.4767
# The estimated fair value of the note at moneyness of 80.0 for 554 time steps and CRR model is: $979.5894
# The estimated fair value of the note at moneyness of 80.0 for 557 time steps and CRR model is: $975.4048
# The estimated fair value of the note at moneyness of 80.0 for 560 time steps and CRR model is: $978.6914
# The estimated fair value of the note at moneyness of 80.0 for 563 time steps and CRR model is: $974.9556
# The estimated fair value of the note at moneyness of 80.0 for 566 time steps and CRR model is: $977.8396
# The estimated fair value of the note at moneyness of 80.0 for 569 time steps and CRR model is: $981.9701
# The estimated fair value of the note at moneyness of 80.0 for 572 time steps and CRR model is: $978.6114
# The estimated fair value of the note at moneyness of 80.0 for 575 time steps and CRR model is: $980.8560
# The estimated fair value of the note at moneyness of 80.0 for 578 time steps and CRR model is: $977.7579
# The estimated fair value of the note at moneyness of 80.0 for 581 time steps and CRR model is: $980.4583
# The estimated fair value of the note at moneyness of 80.0 for 584 time steps and CRR model is: $977.3352
# The estimated fair value of the note at moneyness of 80.0 for 587 time steps and CRR model is: $980.0576
# The estimated fair value of the note at moneyness of 80.0 for 590 time steps and CRR model is: $976.7063
# The estimated fair value of the note at moneyness of 80.0 for 593 time steps and CRR model is: $979.7579
# The estimated fair value of the note at moneyness of 80.0 for 596 time steps and CRR model is: $976.5367
# The estimated fair value of the note at moneyness of 80.0 for 599 time steps and CRR model is: $978.6953
# The estimated fair value of the note at moneyness of 80.0 for 602 time steps and CRR model is: $975.3040
# The estimated fair value of the note at moneyness of 80.0 for 605 time steps and CRR model is: $978.7108
# The estimated fair value of the note at moneyness of 80.0 for 608 time steps and CRR model is: $975.1338
# The estimated fair value of the note at moneyness of 80.0 for 611 time steps and CRR model is: $978.7292
# The estimated fair value of the note at moneyness of 80.0 for 614 time steps and CRR model is: $981.3792
# The estimated fair value of the note at moneyness of 80.0 for 617 time steps and CRR model is: $978.2700
# The estimated fair value of the note at moneyness of 80.0 for 620 time steps and CRR model is: $980.8822
# The estimated fair value of the note at moneyness of 80.0 for 623 time steps and CRR model is: $978.2966
# The estimated fair value of the note at moneyness of 80.0 for 626 time steps and CRR model is: $980.4935
# The estimated fair value of the note at moneyness of 80.0 for 629 time steps and CRR model is: $977.4932
# The estimated fair value of the note at moneyness of 80.0 for 632 time steps and CRR model is: $980.0489
# The estimated fair value of the note at moneyness of 80.0 for 635 time steps and CRR model is: $976.6815
# The estimated fair value of the note at moneyness of 80.0 for 638 time steps and CRR model is: $979.4487
# The estimated fair value of the note at moneyness of 80.0 for 641 time steps and CRR model is: $975.9541
# The estimated fair value of the note at moneyness of 80.0 for 644 time steps and CRR model is: $978.4271
# The estimated fair value of the note at moneyness of 80.0 for 647 time steps and CRR model is: $975.5820
# The estimated fair value of the note at moneyness of 80.0 for 650 time steps and CRR model is: $978.4668
# The estimated fair value of the note at moneyness of 80.0 for 653 time steps and CRR model is: $974.7879
# The estimated fair value of the note at moneyness of 80.0 for 656 time steps and CRR model is: $978.9034
# The estimated fair value of the note at moneyness of 80.0 for 659 time steps and CRR model is: $981.5271
# The estimated fair value of the note at moneyness of 80.0 for 662 time steps and CRR model is: $978.1610
# The estimated fair value of the note at moneyness of 80.0 for 665 time steps and CRR model is: $980.9846
# The estimated fair value of the note at moneyness of 80.0 for 668 time steps and CRR model is: $977.8754
# The estimated fair value of the note at moneyness of 80.0 for 671 time steps and CRR model is: $979.8402
# The estimated fair value of the note at moneyness of 80.0 for 674 time steps and CRR model is: $977.1263
# The estimated fair value of the note at moneyness of 80.0 for 677 time steps and CRR model is: $979.4723
# The estimated fair value of the note at moneyness of 80.0 for 680 time steps and CRR model is: $976.6419
# The estimated fair value of the note at moneyness of 80.0 for 683 time steps and CRR model is: $979.3199
# The estimated fair value of the note at moneyness of 80.0 for 686 time steps and CRR model is: $976.2995
# The estimated fair value of the note at moneyness of 80.0 for 689 time steps and CRR model is: $978.7766
# The estimated fair value of the note at moneyness of 80.0 for 692 time steps and CRR model is: $976.1234
# The estimated fair value of the note at moneyness of 80.0 for 695 time steps and CRR model is: $978.3728
# The estimated fair value of the note at moneyness of 80.0 for 698 time steps and CRR model is: $974.9781
# The estimated fair value of the note at moneyness of 80.0 for 701 time steps and CRR model is: $977.8580
# The estimated fair value of the note at moneyness of 80.0 for 704 time steps and CRR model is: $981.3239
# The estimated fair value of the note at moneyness of 80.0 for 707 time steps and CRR model is: $978.2618
# The estimated fair value of the note at moneyness of 80.0 for 710 time steps and CRR model is: $980.9672
# The estimated fair value of the note at moneyness of 80.0 for 713 time steps and CRR model is: $977.3681
# The estimated fair value of the note at moneyness of 80.0 for 716 time steps and CRR model is: $980.3096
# The estimated fair value of the note at moneyness of 80.0 for 719 time steps and CRR model is: $977.9483
# The estimated fair value of the note at moneyness of 80.0 for 722 time steps and CRR model is: $979.9953
# The estimated fair value of the note at moneyness of 80.0 for 725 time steps and CRR model is: $977.0803
# The estimated fair value of the note at moneyness of 80.0 for 728 time steps and CRR model is: $979.6284
# The estimated fair value of the note at moneyness of 80.0 for 731 time steps and CRR model is: $976.4905
# The estimated fair value of the note at moneyness of 80.0 for 734 time steps and CRR model is: $978.7803
# The estimated fair value of the note at moneyness of 80.0 for 737 time steps and CRR model is: $976.0258
# The estimated fair value of the note at moneyness of 80.0 for 740 time steps and CRR model is: $978.8380
# The estimated fair value of the note at moneyness of 80.0 for 743 time steps and CRR model is: $975.5228
# The estimated fair value of the note at moneyness of 80.0 for 746 time steps and CRR model is: $978.0712
# The estimated fair value of the note at moneyness of 80.0 for 749 time steps and CRR model is: $981.4773
# The estimated fair value of the note at moneyness of 80.0 for 752 time steps and CRR model is: $978.7115
# The estimated fair value of the note at moneyness of 80.0 for 755 time steps and CRR model is: $981.1523
# The estimated fair value of the note at moneyness of 80.0 for 758 time steps and CRR model is: $978.2641
# The estimated fair value of the note at moneyness of 80.0 for 761 time steps and CRR model is: $981.0507
# The estimated fair value of the note at moneyness of 80.0 for 764 time steps and CRR model is: $977.5649
# The estimated fair value of the note at moneyness of 80.0 for 767 time steps and CRR model is: $979.6510
# The estimated fair value of the note at moneyness of 80.0 for 770 time steps and CRR model is: $977.3297
# The estimated fair value of the note at moneyness of 80.0 for 773 time steps and CRR model is: $979.5451
# The estimated fair value of the note at moneyness of 80.0 for 776 time steps and CRR model is: $976.6959
# The estimated fair value of the note at moneyness of 80.0 for 779 time steps and CRR model is: $979.0461
# The estimated fair value of the note at moneyness of 80.0 for 782 time steps and CRR model is: $976.6066
# The estimated fair value of the note at moneyness of 80.0 for 785 time steps and CRR model is: $978.7315
# The estimated fair value of the note at moneyness of 80.0 for 788 time steps and CRR model is: $975.5628
# The estimated fair value of the note at moneyness of 80.0 for 791 time steps and CRR model is: $978.4195
# The estimated fair value of the note at moneyness of 80.0 for 794 time steps and CRR model is: $975.4716
# The estimated fair value of the note at moneyness of 80.0 for 797 time steps and CRR model is: $977.9577
# The estimated fair value of the note at moneyness of 80.0 for 800 time steps and CRR model is: $981.0814
# The estimated fair value of the note at moneyness of 80.0 for 803 time steps and CRR model is: $978.2215
# The estimated fair value of the note at moneyness of 80.0 for 806 time steps and CRR model is: $980.7538
# The estimated fair value of the note at moneyness of 80.0 for 809 time steps and CRR model is: $977.5504
# The estimated fair value of the note at moneyness of 80.0 for 812 time steps and CRR model is: $980.4962
# The estimated fair value of the note at moneyness of 80.0 for 815 time steps and CRR model is: $977.6340
# The estimated fair value of the note at moneyness of 80.0 for 818 time steps and CRR model is: $980.0762
# The estimated fair value of the note at moneyness of 80.0 for 821 time steps and CRR model is: $977.2992
# The estimated fair value of the note at moneyness of 80.0 for 824 time steps and CRR model is: $979.5884
# The estimated fair value of the note at moneyness of 80.0 for 827 time steps and CRR model is: $977.0175
# The estimated fair value of the note at moneyness of 80.0 for 830 time steps and CRR model is: $978.9679
# The estimated fair value of the note at moneyness of 80.0 for 833 time steps and CRR model is: $976.3890
# The estimated fair value of the note at moneyness of 80.0 for 836 time steps and CRR model is: $979.0461
# The estimated fair value of the note at moneyness of 80.0 for 839 time steps and CRR model is: $976.1167
# The estimated fair value of the note at moneyness of 80.0 for 842 time steps and CRR model is: $978.1878
# The estimated fair value of the note at moneyness of 80.0 for 845 time steps and CRR model is: $975.5186
# The estimated fair value of the note at moneyness of 80.0 for 848 time steps and CRR model is: $977.7269
# The estimated fair value of the note at moneyness of 80.0 for 851 time steps and CRR model is: $981.2975
# The estimated fair value of the note at moneyness of 80.0 for 854 time steps and CRR model is: $978.5681
# The estimated fair value of the note at moneyness of 80.0 for 857 time steps and CRR model is: $981.0329
# The estimated fair value of the note at moneyness of 80.0 for 860 time steps and CRR model is: $977.9419
# The estimated fair value of the note at moneyness of 80.0 for 863 time steps and CRR model is: $980.2372
# The estimated fair value of the note at moneyness of 80.0 for 866 time steps and CRR model is: $977.5182
# The estimated fair value of the note at moneyness of 80.0 for 869 time steps and CRR model is: $979.8392
# The estimated fair value of the note at moneyness of 80.0 for 872 time steps and CRR model is: $977.1618
# The estimated fair value of the note at moneyness of 80.0 for 875 time steps and CRR model is: $979.2615
# The estimated fair value of the note at moneyness of 80.0 for 878 time steps and CRR model is: $977.0998
# The estimated fair value of the note at moneyness of 80.0 for 881 time steps and CRR model is: $979.2938
# The estimated fair value of the note at moneyness of 80.0 for 884 time steps and CRR model is: $976.1251
# The estimated fair value of the note at moneyness of 80.0 for 887 time steps and CRR model is: $978.5110
# The estimated fair value of the note at moneyness of 80.0 for 890 time steps and CRR model is: $976.0836
# The estimated fair value of the note at moneyness of 80.0 for 893 time steps and CRR model is: $978.4248
# The estimated fair value of the note at moneyness of 80.0 for 896 time steps and CRR model is: $975.6734
# The estimated fair value of the note at moneyness of 80.0 for 899 time steps and CRR model is: $978.1966
# The estimated fair value of the note at moneyness of 80.0 for 902 time steps and CRR model is: $980.9650
# The estimated fair value of the note at moneyness of 80.0 for 905 time steps and CRR model is: $978.2642
# The estimated fair value of the note at moneyness of 80.0 for 908 time steps and CRR model is: $980.8657
# The estimated fair value of the note at moneyness of 80.0 for 911 time steps and CRR model is: $978.1871
# The estimated fair value of the note at moneyness of 80.0 for 914 time steps and CRR model is: $980.4752
# The estimated fair value of the note at moneyness of 80.0 for 917 time steps and CRR model is: $977.2696
# The estimated fair value of the note at moneyness of 80.0 for 920 time steps and CRR model is: $979.9039
# The estimated fair value of the note at moneyness of 80.0 for 923 time steps and CRR model is: $977.6338
# The estimated fair value of the note at moneyness of 80.0 for 926 time steps and CRR model is: $979.3312
# The estimated fair value of the note at moneyness of 80.0 for 929 time steps and CRR model is: $977.0846
# The estimated fair value of the note at moneyness of 80.0 for 932 time steps and CRR model is: $979.6021
# The estimated fair value of the note at moneyness of 80.0 for 935 time steps and CRR model is: $977.0092
# The estimated fair value of the note at moneyness of 80.0 for 938 time steps and CRR model is: $978.8795
# The estimated fair value of the note at moneyness of 80.0 for 941 time steps and CRR model is: $976.2778
# The estimated fair value of the note at moneyness of 80.0 for 944 time steps and CRR model is: $978.5527
# The estimated fair value of the note at moneyness of 80.0 for 947 time steps and CRR model is: $975.6868
# The estimated fair value of the note at moneyness of 80.0 for 950 time steps and CRR model is: $977.9783
# The estimated fair value of the note at moneyness of 80.0 for 953 time steps and CRR model is: $975.4721
# The estimated fair value of the note at moneyness of 80.0 for 956 time steps and CRR model is: $978.6013
# The estimated fair value of the note at moneyness of 80.0 for 959 time steps and CRR model is: $980.9480
# The estimated fair value of the note at moneyness of 80.0 for 962 time steps and CRR model is: $978.2281
# The estimated fair value of the note at moneyness of 80.0 for 965 time steps and CRR model is: $980.8774
# The estimated fair value of the note at moneyness of 80.0 for 968 time steps and CRR model is: $978.0803
# The estimated fair value of the note at moneyness of 80.0 for 971 time steps and CRR model is: $979.8952
# The estimated fair value of the note at moneyness of 80.0 for 974 time steps and CRR model is: $977.7108
# The estimated fair value of the note at moneyness of 80.0 for 977 time steps and CRR model is: $979.6589
# The estimated fair value of the note at moneyness of 80.0 for 980 time steps and CRR model is: $976.9821
# The estimated fair value of the note at moneyness of 80.0 for 983 time steps and CRR model is: $979.0910
# The estimated fair value of the note at moneyness of 80.0 for 986 time steps and CRR model is: $976.9320
# The estimated fair value of the note at moneyness of 80.0 for 989 time steps and CRR model is: $979.1809
# The estimated fair value of the note at moneyness of 80.0 for 992 time steps and CRR model is: $976.3905
# The estimated fair value of the note at moneyness of 80.0 for 995 time steps and CRR model is: $978.9551
# The estimated fair value of the note at moneyness of 80.0 for 998 time steps and CRR model is: $976.5593

# %%
df_crr = pd.DataFrame({
    'N': N_values,
    'Note_Value': CRR_values
})

# Add better column names and reset index if needed
df_crr = df_crr.reset_index(drop=True)
df_crr.head()
# Out:
#     N  Note_Value
# 0  50  991.013577
# 1  53  977.365317
# 2  56  984.362861
# 3  59  972.045046
# 4  62  979.573647

# %%
# plotting the error results
plt.figure(figsize=(20, 10))
plt.plot(df_crr['N'],df_crr['Note_Value'],'o', markersize=3, label='Cox, Ross and Rubinstein (1979)')
plt.xlabel('Number of time steps (N)')
plt.ylabel('CRR Note Value')
plt.title('CRR Note Value vs. Number of Time Steps')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">IX) Increasing the Number of Steps from 50 till 1000 and plotting the value graph for 80 Moneyness 'RB' Model==></span>
# </div>

# %%
N_values = range(50, 1000, 3)
RB_values = []

for i in N_values:
    S, p, u, d, model = Stock_tree(i, S0, B, sigma, r1, D, T0_T2, model="RB")
    note_value = Note_Value(S, p, i, sigma, T0_T2, T1_T3, r2, model)
    RB_values.append(note_value)
# Out:
# The estimated fair value of the note at moneyness of 80.0 for 50 time steps and RB model is: $987.1720
# The estimated fair value of the note at moneyness of 80.0 for 53 time steps and RB model is: $975.3254
# The estimated fair value of the note at moneyness of 80.0 for 56 time steps and RB model is: $984.7267
# The estimated fair value of the note at moneyness of 80.0 for 59 time steps and RB model is: $972.5020
# The estimated fair value of the note at moneyness of 80.0 for 62 time steps and RB model is: $980.1165
# The estimated fair value of the note at moneyness of 80.0 for 65 time steps and RB model is: $970.3487
# The estimated fair value of the note at moneyness of 80.0 for 68 time steps and RB model is: $977.1904
# The estimated fair value of the note at moneyness of 80.0 for 71 time steps and RB model is: $985.8739
# The estimated fair value of the note at moneyness of 80.0 for 74 time steps and RB model is: $975.7457
# The estimated fair value of the note at moneyness of 80.0 for 77 time steps and RB model is: $983.3843
# The estimated fair value of the note at moneyness of 80.0 for 80 time steps and RB model is: $973.4571
# The estimated fair value of the note at moneyness of 80.0 for 83 time steps and RB model is: $981.3657
# The estimated fair value of the note at moneyness of 80.0 for 86 time steps and RB model is: $971.0872
# The estimated fair value of the note at moneyness of 80.0 for 89 time steps and RB model is: $978.6842
# The estimated fair value of the note at moneyness of 80.0 for 92 time steps and RB model is: $984.3487
# The estimated fair value of the note at moneyness of 80.0 for 95 time steps and RB model is: $977.1119
# The estimated fair value of the note at moneyness of 80.0 for 98 time steps and RB model is: $983.0237
# The estimated fair value of the note at moneyness of 80.0 for 101 time steps and RB model is: $974.8803
# The estimated fair value of the note at moneyness of 80.0 for 104 time steps and RB model is: $980.6714
# The estimated fair value of the note at moneyness of 80.0 for 107 time steps and RB model is: $971.5678
# The estimated fair value of the note at moneyness of 80.0 for 110 time steps and RB model is: $979.3282
# The estimated fair value of the note at moneyness of 80.0 for 113 time steps and RB model is: $984.6071
# The estimated fair value of the note at moneyness of 80.0 for 116 time steps and RB model is: $977.3245
# The estimated fair value of the note at moneyness of 80.0 for 119 time steps and RB model is: $982.6449
# The estimated fair value of the note at moneyness of 80.0 for 122 time steps and RB model is: $975.3522
# The estimated fair value of the note at moneyness of 80.0 for 125 time steps and RB model is: $981.6571
# The estimated fair value of the note at moneyness of 80.0 for 128 time steps and RB model is: $974.7772
# The estimated fair value of the note at moneyness of 80.0 for 131 time steps and RB model is: $980.0425
# The estimated fair value of the note at moneyness of 80.0 for 134 time steps and RB model is: $972.7719
# The estimated fair value of the note at moneyness of 80.0 for 137 time steps and RB model is: $978.4084
# The estimated fair value of the note at moneyness of 80.0 for 140 time steps and RB model is: $983.9862
# The estimated fair value of the note at moneyness of 80.0 for 143 time steps and RB model is: $977.6419
# The estimated fair value of the note at moneyness of 80.0 for 146 time steps and RB model is: $982.8510
# The estimated fair value of the note at moneyness of 80.0 for 149 time steps and RB model is: $975.9609
# The estimated fair value of the note at moneyness of 80.0 for 152 time steps and RB model is: $981.0192
# The estimated fair value of the note at moneyness of 80.0 for 155 time steps and RB model is: $974.3407
# The estimated fair value of the note at moneyness of 80.0 for 158 time steps and RB model is: $979.9984
# The estimated fair value of the note at moneyness of 80.0 for 161 time steps and RB model is: $973.2585
# The estimated fair value of the note at moneyness of 80.0 for 164 time steps and RB model is: $978.8586
# The estimated fair value of the note at moneyness of 80.0 for 167 time steps and RB model is: $983.6014
# The estimated fair value of the note at moneyness of 80.0 for 170 time steps and RB model is: $977.5420
# The estimated fair value of the note at moneyness of 80.0 for 173 time steps and RB model is: $982.3011
# The estimated fair value of the note at moneyness of 80.0 for 176 time steps and RB model is: $977.3995
# The estimated fair value of the note at moneyness of 80.0 for 179 time steps and RB model is: $981.2030
# The estimated fair value of the note at moneyness of 80.0 for 182 time steps and RB model is: $975.9190
# The estimated fair value of the note at moneyness of 80.0 for 185 time steps and RB model is: $979.7771
# The estimated fair value of the note at moneyness of 80.0 for 188 time steps and RB model is: $974.6037
# The estimated fair value of the note at moneyness of 80.0 for 191 time steps and RB model is: $979.4681
# The estimated fair value of the note at moneyness of 80.0 for 194 time steps and RB model is: $972.6692
# The estimated fair value of the note at moneyness of 80.0 for 197 time steps and RB model is: $977.6543
# The estimated fair value of the note at moneyness of 80.0 for 200 time steps and RB model is: $983.4167
# The estimated fair value of the note at moneyness of 80.0 for 203 time steps and RB model is: $977.4776
# The estimated fair value of the note at moneyness of 80.0 for 206 time steps and RB model is: $981.9494
# The estimated fair value of the note at moneyness of 80.0 for 209 time steps and RB model is: $976.6360
# The estimated fair value of the note at moneyness of 80.0 for 212 time steps and RB model is: $981.1405
# The estimated fair value of the note at moneyness of 80.0 for 215 time steps and RB model is: $975.9418
# The estimated fair value of the note at moneyness of 80.0 for 218 time steps and RB model is: $980.8632
# The estimated fair value of the note at moneyness of 80.0 for 221 time steps and RB model is: $974.2926
# The estimated fair value of the note at moneyness of 80.0 for 224 time steps and RB model is: $979.1340
# The estimated fair value of the note at moneyness of 80.0 for 227 time steps and RB model is: $974.1243
# The estimated fair value of the note at moneyness of 80.0 for 230 time steps and RB model is: $978.9283
# The estimated fair value of the note at moneyness of 80.0 for 233 time steps and RB model is: $982.5253
# The estimated fair value of the note at moneyness of 80.0 for 236 time steps and RB model is: $977.3932
# The estimated fair value of the note at moneyness of 80.0 for 239 time steps and RB model is: $981.5442
# The estimated fair value of the note at moneyness of 80.0 for 242 time steps and RB model is: $976.0147
# The estimated fair value of the note at moneyness of 80.0 for 245 time steps and RB model is: $981.3333
# The estimated fair value of the note at moneyness of 80.0 for 248 time steps and RB model is: $976.8468
# The estimated fair value of the note at moneyness of 80.0 for 251 time steps and RB model is: $981.0008
# The estimated fair value of the note at moneyness of 80.0 for 254 time steps and RB model is: $975.4911
# The estimated fair value of the note at moneyness of 80.0 for 257 time steps and RB model is: $979.1142
# The estimated fair value of the note at moneyness of 80.0 for 260 time steps and RB model is: $974.6532
# The estimated fair value of the note at moneyness of 80.0 for 263 time steps and RB model is: $978.7904
# The estimated fair value of the note at moneyness of 80.0 for 266 time steps and RB model is: $973.8898
# The estimated fair value of the note at moneyness of 80.0 for 269 time steps and RB model is: $977.9703
# The estimated fair value of the note at moneyness of 80.0 for 272 time steps and RB model is: $981.2341
# The estimated fair value of the note at moneyness of 80.0 for 275 time steps and RB model is: $976.6708
# The estimated fair value of the note at moneyness of 80.0 for 278 time steps and RB model is: $981.9707
# The estimated fair value of the note at moneyness of 80.0 for 281 time steps and RB model is: $977.1823
# The estimated fair value of the note at moneyness of 80.0 for 284 time steps and RB model is: $981.1581
# The estimated fair value of the note at moneyness of 80.0 for 287 time steps and RB model is: $976.1027
# The estimated fair value of the note at moneyness of 80.0 for 290 time steps and RB model is: $980.0105
# The estimated fair value of the note at moneyness of 80.0 for 293 time steps and RB model is: $975.3896
# The estimated fair value of the note at moneyness of 80.0 for 296 time steps and RB model is: $979.1608
# The estimated fair value of the note at moneyness of 80.0 for 299 time steps and RB model is: $975.0514
# The estimated fair value of the note at moneyness of 80.0 for 302 time steps and RB model is: $978.8366
# The estimated fair value of the note at moneyness of 80.0 for 305 time steps and RB model is: $973.7743
# The estimated fair value of the note at moneyness of 80.0 for 308 time steps and RB model is: $978.0292
# The estimated fair value of the note at moneyness of 80.0 for 311 time steps and RB model is: $981.6516
# The estimated fair value of the note at moneyness of 80.0 for 314 time steps and RB model is: $977.1905
# The estimated fair value of the note at moneyness of 80.0 for 317 time steps and RB model is: $981.1459
# The estimated fair value of the note at moneyness of 80.0 for 320 time steps and RB model is: $976.8025
# The estimated fair value of the note at moneyness of 80.0 for 323 time steps and RB model is: $980.7767
# The estimated fair value of the note at moneyness of 80.0 for 326 time steps and RB model is: $976.2735
# The estimated fair value of the note at moneyness of 80.0 for 329 time steps and RB model is: $980.4496
# The estimated fair value of the note at moneyness of 80.0 for 332 time steps and RB model is: $975.0927
# The estimated fair value of the note at moneyness of 80.0 for 335 time steps and RB model is: $979.0365
# The estimated fair value of the note at moneyness of 80.0 for 338 time steps and RB model is: $976.1508
# The estimated fair value of the note at moneyness of 80.0 for 341 time steps and RB model is: $979.2340
# The estimated fair value of the note at moneyness of 80.0 for 344 time steps and RB model is: $974.4777
# The estimated fair value of the note at moneyness of 80.0 for 347 time steps and RB model is: $978.4219
# The estimated fair value of the note at moneyness of 80.0 for 350 time steps and RB model is: $981.8478
# The estimated fair value of the note at moneyness of 80.0 for 353 time steps and RB model is: $978.0776
# The estimated fair value of the note at moneyness of 80.0 for 356 time steps and RB model is: $981.4675
# The estimated fair value of the note at moneyness of 80.0 for 359 time steps and RB model is: $977.2945
# The estimated fair value of the note at moneyness of 80.0 for 362 time steps and RB model is: $981.2197
# The estimated fair value of the note at moneyness of 80.0 for 365 time steps and RB model is: $976.7892
# The estimated fair value of the note at moneyness of 80.0 for 368 time steps and RB model is: $980.6114
# The estimated fair value of the note at moneyness of 80.0 for 371 time steps and RB model is: $976.3571
# The estimated fair value of the note at moneyness of 80.0 for 374 time steps and RB model is: $980.0953
# The estimated fair value of the note at moneyness of 80.0 for 377 time steps and RB model is: $976.2644
# The estimated fair value of the note at moneyness of 80.0 for 380 time steps and RB model is: $979.8744
# The estimated fair value of the note at moneyness of 80.0 for 383 time steps and RB model is: $975.5283
# The estimated fair value of the note at moneyness of 80.0 for 386 time steps and RB model is: $978.8267
# The estimated fair value of the note at moneyness of 80.0 for 389 time steps and RB model is: $975.0011
# The estimated fair value of the note at moneyness of 80.0 for 392 time steps and RB model is: $979.2724
# The estimated fair value of the note at moneyness of 80.0 for 395 time steps and RB model is: $981.7965
# The estimated fair value of the note at moneyness of 80.0 for 398 time steps and RB model is: $977.7410
# The estimated fair value of the note at moneyness of 80.0 for 401 time steps and RB model is: $981.5085
# The estimated fair value of the note at moneyness of 80.0 for 404 time steps and RB model is: $977.3521
# The estimated fair value of the note at moneyness of 80.0 for 407 time steps and RB model is: $981.2742
# The estimated fair value of the note at moneyness of 80.0 for 410 time steps and RB model is: $977.3502
# The estimated fair value of the note at moneyness of 80.0 for 413 time steps and RB model is: $980.3117
# The estimated fair value of the note at moneyness of 80.0 for 416 time steps and RB model is: $976.8213
# The estimated fair value of the note at moneyness of 80.0 for 419 time steps and RB model is: $979.8415
# The estimated fair value of the note at moneyness of 80.0 for 422 time steps and RB model is: $976.3597
# The estimated fair value of the note at moneyness of 80.0 for 425 time steps and RB model is: $979.5822
# The estimated fair value of the note at moneyness of 80.0 for 428 time steps and RB model is: $975.4223
# The estimated fair value of the note at moneyness of 80.0 for 431 time steps and RB model is: $978.9251
# The estimated fair value of the note at moneyness of 80.0 for 434 time steps and RB model is: $975.7586
# The estimated fair value of the note at moneyness of 80.0 for 437 time steps and RB model is: $978.5064
# The estimated fair value of the note at moneyness of 80.0 for 440 time steps and RB model is: $974.1924
# The estimated fair value of the note at moneyness of 80.0 for 443 time steps and RB model is: $978.2057
# The estimated fair value of the note at moneyness of 80.0 for 446 time steps and RB model is: $981.2560
# The estimated fair value of the note at moneyness of 80.0 for 449 time steps and RB model is: $977.7803
# The estimated fair value of the note at moneyness of 80.0 for 452 time steps and RB model is: $980.9219
# The estimated fair value of the note at moneyness of 80.0 for 455 time steps and RB model is: $977.2110
# The estimated fair value of the note at moneyness of 80.0 for 458 time steps and RB model is: $980.5866
# The estimated fair value of the note at moneyness of 80.0 for 461 time steps and RB model is: $976.7681
# The estimated fair value of the note at moneyness of 80.0 for 464 time steps and RB model is: $979.9472
# The estimated fair value of the note at moneyness of 80.0 for 467 time steps and RB model is: $977.0328
# The estimated fair value of the note at moneyness of 80.0 for 470 time steps and RB model is: $979.7624
# The estimated fair value of the note at moneyness of 80.0 for 473 time steps and RB model is: $976.1622
# The estimated fair value of the note at moneyness of 80.0 for 476 time steps and RB model is: $979.2234
# The estimated fair value of the note at moneyness of 80.0 for 479 time steps and RB model is: $975.8308
# The estimated fair value of the note at moneyness of 80.0 for 482 time steps and RB model is: $978.5541
# The estimated fair value of the note at moneyness of 80.0 for 485 time steps and RB model is: $975.4734
# The estimated fair value of the note at moneyness of 80.0 for 488 time steps and RB model is: $978.7986
# The estimated fair value of the note at moneyness of 80.0 for 491 time steps and RB model is: $982.0657
# The estimated fair value of the note at moneyness of 80.0 for 494 time steps and RB model is: $978.2226
# The estimated fair value of the note at moneyness of 80.0 for 497 time steps and RB model is: $980.9768
# The estimated fair value of the note at moneyness of 80.0 for 500 time steps and RB model is: $977.6676
# The estimated fair value of the note at moneyness of 80.0 for 503 time steps and RB model is: $981.3416
# The estimated fair value of the note at moneyness of 80.0 for 506 time steps and RB model is: $977.4830
# The estimated fair value of the note at moneyness of 80.0 for 509 time steps and RB model is: $980.5759
# The estimated fair value of the note at moneyness of 80.0 for 512 time steps and RB model is: $977.1276
# The estimated fair value of the note at moneyness of 80.0 for 515 time steps and RB model is: $980.2340
# The estimated fair value of the note at moneyness of 80.0 for 518 time steps and RB model is: $976.7656
# The estimated fair value of the note at moneyness of 80.0 for 521 time steps and RB model is: $979.6582
# The estimated fair value of the note at moneyness of 80.0 for 524 time steps and RB model is: $976.2531
# The estimated fair value of the note at moneyness of 80.0 for 527 time steps and RB model is: $979.5991
# The estimated fair value of the note at moneyness of 80.0 for 530 time steps and RB model is: $976.1021
# The estimated fair value of the note at moneyness of 80.0 for 533 time steps and RB model is: $978.7794
# The estimated fair value of the note at moneyness of 80.0 for 536 time steps and RB model is: $975.7552
# The estimated fair value of the note at moneyness of 80.0 for 539 time steps and RB model is: $978.3704
# The estimated fair value of the note at moneyness of 80.0 for 542 time steps and RB model is: $975.0287
# The estimated fair value of the note at moneyness of 80.0 for 545 time steps and RB model is: $978.2430
# The estimated fair value of the note at moneyness of 80.0 for 548 time steps and RB model is: $981.1844
# The estimated fair value of the note at moneyness of 80.0 for 551 time steps and RB model is: $977.4700
# The estimated fair value of the note at moneyness of 80.0 for 554 time steps and RB model is: $980.6301
# The estimated fair value of the note at moneyness of 80.0 for 557 time steps and RB model is: $977.6019
# The estimated fair value of the note at moneyness of 80.0 for 560 time steps and RB model is: $980.2961
# The estimated fair value of the note at moneyness of 80.0 for 563 time steps and RB model is: $976.9148
# The estimated fair value of the note at moneyness of 80.0 for 566 time steps and RB model is: $980.1938
# The estimated fair value of the note at moneyness of 80.0 for 569 time steps and RB model is: $977.1789
# The estimated fair value of the note at moneyness of 80.0 for 572 time steps and RB model is: $979.7199
# The estimated fair value of the note at moneyness of 80.0 for 575 time steps and RB model is: $976.6641
# The estimated fair value of the note at moneyness of 80.0 for 578 time steps and RB model is: $979.4045
# The estimated fair value of the note at moneyness of 80.0 for 581 time steps and RB model is: $976.3573
# The estimated fair value of the note at moneyness of 80.0 for 584 time steps and RB model is: $979.1017
# The estimated fair value of the note at moneyness of 80.0 for 587 time steps and RB model is: $976.0496
# The estimated fair value of the note at moneyness of 80.0 for 590 time steps and RB model is: $978.9729
# The estimated fair value of the note at moneyness of 80.0 for 593 time steps and RB model is: $975.5386
# The estimated fair value of the note at moneyness of 80.0 for 596 time steps and RB model is: $978.5119
# The estimated fair value of the note at moneyness of 80.0 for 599 time steps and RB model is: $975.6285
# The estimated fair value of the note at moneyness of 80.0 for 602 time steps and RB model is: $978.3383
# The estimated fair value of the note at moneyness of 80.0 for 605 time steps and RB model is: $981.2022
# The estimated fair value of the note at moneyness of 80.0 for 608 time steps and RB model is: $977.8877
# The estimated fair value of the note at moneyness of 80.0 for 611 time steps and RB model is: $980.8872
# The estimated fair value of the note at moneyness of 80.0 for 614 time steps and RB model is: $977.3920
# The estimated fair value of the note at moneyness of 80.0 for 617 time steps and RB model is: $980.2228
# The estimated fair value of the note at moneyness of 80.0 for 620 time steps and RB model is: $977.3132
# The estimated fair value of the note at moneyness of 80.0 for 623 time steps and RB model is: $979.9178
# The estimated fair value of the note at moneyness of 80.0 for 626 time steps and RB model is: $977.0619
# The estimated fair value of the note at moneyness of 80.0 for 629 time steps and RB model is: $979.7085
# The estimated fair value of the note at moneyness of 80.0 for 632 time steps and RB model is: $977.1748
# The estimated fair value of the note at moneyness of 80.0 for 635 time steps and RB model is: $979.4553
# The estimated fair value of the note at moneyness of 80.0 for 638 time steps and RB model is: $976.7047
# The estimated fair value of the note at moneyness of 80.0 for 641 time steps and RB model is: $979.4775
# The estimated fair value of the note at moneyness of 80.0 for 644 time steps and RB model is: $976.1528
# The estimated fair value of the note at moneyness of 80.0 for 647 time steps and RB model is: $978.4224
# The estimated fair value of the note at moneyness of 80.0 for 650 time steps and RB model is: $975.6787
# The estimated fair value of the note at moneyness of 80.0 for 653 time steps and RB model is: $978.3422
# The estimated fair value of the note at moneyness of 80.0 for 656 time steps and RB model is: $975.2954
# The estimated fair value of the note at moneyness of 80.0 for 659 time steps and RB model is: $978.1256
# The estimated fair value of the note at moneyness of 80.0 for 662 time steps and RB model is: $980.7810
# The estimated fair value of the note at moneyness of 80.0 for 665 time steps and RB model is: $978.4115
# The estimated fair value of the note at moneyness of 80.0 for 668 time steps and RB model is: $980.7619
# The estimated fair value of the note at moneyness of 80.0 for 671 time steps and RB model is: $977.3683
# The estimated fair value of the note at moneyness of 80.0 for 674 time steps and RB model is: $980.5019
# The estimated fair value of the note at moneyness of 80.0 for 677 time steps and RB model is: $977.5253
# The estimated fair value of the note at moneyness of 80.0 for 680 time steps and RB model is: $980.0680
# The estimated fair value of the note at moneyness of 80.0 for 683 time steps and RB model is: $977.4548
# The estimated fair value of the note at moneyness of 80.0 for 686 time steps and RB model is: $979.7993
# The estimated fair value of the note at moneyness of 80.0 for 689 time steps and RB model is: $976.6506
# The estimated fair value of the note at moneyness of 80.0 for 692 time steps and RB model is: $979.7149
# The estimated fair value of the note at moneyness of 80.0 for 695 time steps and RB model is: $977.3193
# The estimated fair value of the note at moneyness of 80.0 for 698 time steps and RB model is: $979.4946
# The estimated fair value of the note at moneyness of 80.0 for 701 time steps and RB model is: $976.5410
# The estimated fair value of the note at moneyness of 80.0 for 704 time steps and RB model is: $979.2108
# The estimated fair value of the note at moneyness of 80.0 for 707 time steps and RB model is: $976.0582
# The estimated fair value of the note at moneyness of 80.0 for 710 time steps and RB model is: $978.6131
# The estimated fair value of the note at moneyness of 80.0 for 713 time steps and RB model is: $975.6854
# The estimated fair value of the note at moneyness of 80.0 for 716 time steps and RB model is: $977.9423
# The estimated fair value of the note at moneyness of 80.0 for 719 time steps and RB model is: $975.2805
# The estimated fair value of the note at moneyness of 80.0 for 722 time steps and RB model is: $978.1068
# The estimated fair value of the note at moneyness of 80.0 for 725 time steps and RB model is: $980.3779
# The estimated fair value of the note at moneyness of 80.0 for 728 time steps and RB model is: $977.8751
# The estimated fair value of the note at moneyness of 80.0 for 731 time steps and RB model is: $980.3483
# The estimated fair value of the note at moneyness of 80.0 for 734 time steps and RB model is: $977.9092
# The estimated fair value of the note at moneyness of 80.0 for 737 time steps and RB model is: $980.7178
# The estimated fair value of the note at moneyness of 80.0 for 740 time steps and RB model is: $977.6892
# The estimated fair value of the note at moneyness of 80.0 for 743 time steps and RB model is: $979.8514
# The estimated fair value of the note at moneyness of 80.0 for 746 time steps and RB model is: $977.5235
# The estimated fair value of the note at moneyness of 80.0 for 749 time steps and RB model is: $979.8428
# The estimated fair value of the note at moneyness of 80.0 for 752 time steps and RB model is: $976.9795
# The estimated fair value of the note at moneyness of 80.0 for 755 time steps and RB model is: $979.6064
# The estimated fair value of the note at moneyness of 80.0 for 758 time steps and RB model is: $976.9921
# The estimated fair value of the note at moneyness of 80.0 for 761 time steps and RB model is: $979.2009
# The estimated fair value of the note at moneyness of 80.0 for 764 time steps and RB model is: $976.0467
# The estimated fair value of the note at moneyness of 80.0 for 767 time steps and RB model is: $978.9606
# The estimated fair value of the note at moneyness of 80.0 for 770 time steps and RB model is: $976.0187
# The estimated fair value of the note at moneyness of 80.0 for 773 time steps and RB model is: $978.5685
# The estimated fair value of the note at moneyness of 80.0 for 776 time steps and RB model is: $975.8113
# The estimated fair value of the note at moneyness of 80.0 for 779 time steps and RB model is: $978.5377
# The estimated fair value of the note at moneyness of 80.0 for 782 time steps and RB model is: $975.4717
# The estimated fair value of the note at moneyness of 80.0 for 785 time steps and RB model is: $978.3473
# The estimated fair value of the note at moneyness of 80.0 for 788 time steps and RB model is: $980.1633
# The estimated fair value of the note at moneyness of 80.0 for 791 time steps and RB model is: $978.5310
# The estimated fair value of the note at moneyness of 80.0 for 794 time steps and RB model is: $980.8269
# The estimated fair value of the note at moneyness of 80.0 for 797 time steps and RB model is: $978.2629
# The estimated fair value of the note at moneyness of 80.0 for 800 time steps and RB model is: $980.6182
# The estimated fair value of the note at moneyness of 80.0 for 803 time steps and RB model is: $978.0695
# The estimated fair value of the note at moneyness of 80.0 for 806 time steps and RB model is: $980.0478
# The estimated fair value of the note at moneyness of 80.0 for 809 time steps and RB model is: $977.4981
# The estimated fair value of the note at moneyness of 80.0 for 812 time steps and RB model is: $980.2155
# The estimated fair value of the note at moneyness of 80.0 for 815 time steps and RB model is: $977.3082
# The estimated fair value of the note at moneyness of 80.0 for 818 time steps and RB model is: $979.4503
# The estimated fair value of the note at moneyness of 80.0 for 821 time steps and RB model is: $976.8088
# The estimated fair value of the note at moneyness of 80.0 for 824 time steps and RB model is: $979.0690
# The estimated fair value of the note at moneyness of 80.0 for 827 time steps and RB model is: $976.2487
# The estimated fair value of the note at moneyness of 80.0 for 830 time steps and RB model is: $978.8660
# The estimated fair value of the note at moneyness of 80.0 for 833 time steps and RB model is: $975.7015
# The estimated fair value of the note at moneyness of 80.0 for 836 time steps and RB model is: $978.7161
# The estimated fair value of the note at moneyness of 80.0 for 839 time steps and RB model is: $975.8961
# The estimated fair value of the note at moneyness of 80.0 for 842 time steps and RB model is: $978.3622
# The estimated fair value of the note at moneyness of 80.0 for 845 time steps and RB model is: $975.6584
# The estimated fair value of the note at moneyness of 80.0 for 848 time steps and RB model is: $978.2529
# The estimated fair value of the note at moneyness of 80.0 for 851 time steps and RB model is: $980.9403
# The estimated fair value of the note at moneyness of 80.0 for 854 time steps and RB model is: $978.8173
# The estimated fair value of the note at moneyness of 80.0 for 857 time steps and RB model is: $981.0682
# The estimated fair value of the note at moneyness of 80.0 for 860 time steps and RB model is: $977.9371
# The estimated fair value of the note at moneyness of 80.0 for 863 time steps and RB model is: $980.3651
# The estimated fair value of the note at moneyness of 80.0 for 866 time steps and RB model is: $977.9645
# The estimated fair value of the note at moneyness of 80.0 for 869 time steps and RB model is: $980.3177
# The estimated fair value of the note at moneyness of 80.0 for 872 time steps and RB model is: $977.7691
# The estimated fair value of the note at moneyness of 80.0 for 875 time steps and RB model is: $980.1544
# The estimated fair value of the note at moneyness of 80.0 for 878 time steps and RB model is: $977.4491
# The estimated fair value of the note at moneyness of 80.0 for 881 time steps and RB model is: $979.9613
# The estimated fair value of the note at moneyness of 80.0 for 884 time steps and RB model is: $976.9098
# The estimated fair value of the note at moneyness of 80.0 for 887 time steps and RB model is: $979.2594
# The estimated fair value of the note at moneyness of 80.0 for 890 time steps and RB model is: $976.5982
# The estimated fair value of the note at moneyness of 80.0 for 893 time steps and RB model is: $978.9559
# The estimated fair value of the note at moneyness of 80.0 for 896 time steps and RB model is: $976.5423
# The estimated fair value of the note at moneyness of 80.0 for 899 time steps and RB model is: $978.4645
# The estimated fair value of the note at moneyness of 80.0 for 902 time steps and RB model is: $976.3852
# The estimated fair value of the note at moneyness of 80.0 for 905 time steps and RB model is: $978.6089
# The estimated fair value of the note at moneyness of 80.0 for 908 time steps and RB model is: $975.9770
# The estimated fair value of the note at moneyness of 80.0 for 911 time steps and RB model is: $978.4995
# The estimated fair value of the note at moneyness of 80.0 for 914 time steps and RB model is: $976.4180
# The estimated fair value of the note at moneyness of 80.0 for 917 time steps and RB model is: $978.7262
# The estimated fair value of the note at moneyness of 80.0 for 920 time steps and RB model is: $981.0573
# The estimated fair value of the note at moneyness of 80.0 for 923 time steps and RB model is: $978.2581
# The estimated fair value of the note at moneyness of 80.0 for 926 time steps and RB model is: $980.5516
# The estimated fair value of the note at moneyness of 80.0 for 929 time steps and RB model is: $978.1107
# The estimated fair value of the note at moneyness of 80.0 for 932 time steps and RB model is: $980.5646
# The estimated fair value of the note at moneyness of 80.0 for 935 time steps and RB model is: $977.7958
# The estimated fair value of the note at moneyness of 80.0 for 938 time steps and RB model is: $980.2562
# The estimated fair value of the note at moneyness of 80.0 for 941 time steps and RB model is: $977.1265
# The estimated fair value of the note at moneyness of 80.0 for 944 time steps and RB model is: $979.7575
# The estimated fair value of the note at moneyness of 80.0 for 947 time steps and RB model is: $977.5657
# The estimated fair value of the note at moneyness of 80.0 for 950 time steps and RB model is: $979.2788
# The estimated fair value of the note at moneyness of 80.0 for 953 time steps and RB model is: $977.1126
# The estimated fair value of the note at moneyness of 80.0 for 956 time steps and RB model is: $979.6244
# The estimated fair value of the note at moneyness of 80.0 for 959 time steps and RB model is: $977.1383
# The estimated fair value of the note at moneyness of 80.0 for 962 time steps and RB model is: $979.0028
# The estimated fair value of the note at moneyness of 80.0 for 965 time steps and RB model is: $976.6211
# The estimated fair value of the note at moneyness of 80.0 for 968 time steps and RB model is: $978.8962
# The estimated fair value of the note at moneyness of 80.0 for 971 time steps and RB model is: $976.2354
# The estimated fair value of the note at moneyness of 80.0 for 974 time steps and RB model is: $978.6023
# The estimated fair value of the note at moneyness of 80.0 for 977 time steps and RB model is: $976.7880
# The estimated fair value of the note at moneyness of 80.0 for 980 time steps and RB model is: $978.6382
# The estimated fair value of the note at moneyness of 80.0 for 983 time steps and RB model is: $976.6438
# The estimated fair value of the note at moneyness of 80.0 for 986 time steps and RB model is: $978.6728
# The estimated fair value of the note at moneyness of 80.0 for 989 time steps and RB model is: $976.5199
# The estimated fair value of the note at moneyness of 80.0 for 992 time steps and RB model is: $978.5480
# The estimated fair value of the note at moneyness of 80.0 for 995 time steps and RB model is: $980.4352
# The estimated fair value of the note at moneyness of 80.0 for 998 time steps and RB model is: $978.3310

# %%
df_rb = pd.DataFrame({
    'N': N_values,
    'Note_Value': RB_values
})

# Add better column names and reset index if needed
df_rb = df_rb.reset_index(drop=True)
df_rb.head()
# Out:
#     N  Note_Value
# 0  50  987.171953
# 1  53  975.325351
# 2  56  984.726675
# 3  59  972.501981
# 4  62  980.116536

# %%
# plotting the error results
plt.figure(figsize=(20, 10))
plt.plot(df_rb['N'],df_rb['Note_Value'],'o', markersize=3, label='Rendleman and Bartter (1979)')
plt.xlabel('Number of time steps (N)')
plt.ylabel('RB Note Value')
plt.title('RB Note Value vs. Number of Time Steps')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">X) Increasing the Number of Steps from 50 till 1000 and plotting the value graph for 80 Moneyness 'LR' Model==></span>
# </div>

# %%
N_values = range(50, 1000, 3)
LR_values = []

for i in N_values:
    S, p, u, d, model = Stock_tree(i, S0, B, sigma, r1, D, T0_T2, model="LR")
    note_value = Note_Value(S, p, i, sigma, T0_T2, T1_T3, r2, model)
    LR_values.append(note_value)
# Out:
# The estimated fair value of the note at moneyness of 80.0 for 50 time steps and LR model is: $992.0672
# The estimated fair value of the note at moneyness of 80.0 for 53 time steps and LR model is: $981.1540
# The estimated fair value of the note at moneyness of 80.0 for 56 time steps and LR model is: $989.3399
# The estimated fair value of the note at moneyness of 80.0 for 59 time steps and LR model is: $979.9436
# The estimated fair value of the note at moneyness of 80.0 for 62 time steps and LR model is: $989.1566
# The estimated fair value of the note at moneyness of 80.0 for 65 time steps and LR model is: $979.1375
# The estimated fair value of the note at moneyness of 80.0 for 68 time steps and LR model is: $987.3525
# The estimated fair value of the note at moneyness of 80.0 for 71 time steps and LR model is: $978.5384
# The estimated fair value of the note at moneyness of 80.0 for 74 time steps and LR model is: $986.6814
# The estimated fair value of the note at moneyness of 80.0 for 77 time steps and LR model is: $979.0307
# The estimated fair value of the note at moneyness of 80.0 for 80 time steps and LR model is: $987.0213
# The estimated fair value of the note at moneyness of 80.0 for 83 time steps and LR model is: $978.8119
# The estimated fair value of the note at moneyness of 80.0 for 86 time steps and LR model is: $987.2380
# The estimated fair value of the note at moneyness of 80.0 for 89 time steps and LR model is: $979.4092
# The estimated fair value of the note at moneyness of 80.0 for 92 time steps and LR model is: $986.1878
# The estimated fair value of the note at moneyness of 80.0 for 95 time steps and LR model is: $978.0512
# The estimated fair value of the note at moneyness of 80.0 for 98 time steps and LR model is: $985.9254
# The estimated fair value of the note at moneyness of 80.0 for 101 time steps and LR model is: $977.8684
# The estimated fair value of the note at moneyness of 80.0 for 104 time steps and LR model is: $985.6187
# The estimated fair value of the note at moneyness of 80.0 for 107 time steps and LR model is: $978.7617
# The estimated fair value of the note at moneyness of 80.0 for 110 time steps and LR model is: $986.7761
# The estimated fair value of the note at moneyness of 80.0 for 113 time steps and LR model is: $979.0926
# The estimated fair value of the note at moneyness of 80.0 for 116 time steps and LR model is: $986.4443
# The estimated fair value of the note at moneyness of 80.0 for 119 time steps and LR model is: $978.9632
# The estimated fair value of the note at moneyness of 80.0 for 122 time steps and LR model is: $986.2888
# The estimated fair value of the note at moneyness of 80.0 for 125 time steps and LR model is: $979.9656
# The estimated fair value of the note at moneyness of 80.0 for 128 time steps and LR model is: $985.1738
# The estimated fair value of the note at moneyness of 80.0 for 131 time steps and LR model is: $978.5066
# The estimated fair value of the note at moneyness of 80.0 for 134 time steps and LR model is: $984.5741
# The estimated fair value of the note at moneyness of 80.0 for 137 time steps and LR model is: $979.0050
# The estimated fair value of the note at moneyness of 80.0 for 140 time steps and LR model is: $984.9412
# The estimated fair value of the note at moneyness of 80.0 for 143 time steps and LR model is: $978.5594
# The estimated fair value of the note at moneyness of 80.0 for 146 time steps and LR model is: $985.3146
# The estimated fair value of the note at moneyness of 80.0 for 149 time steps and LR model is: $979.3318
# The estimated fair value of the note at moneyness of 80.0 for 152 time steps and LR model is: $984.9201
# The estimated fair value of the note at moneyness of 80.0 for 155 time steps and LR model is: $978.7726
# The estimated fair value of the note at moneyness of 80.0 for 158 time steps and LR model is: $984.4602
# The estimated fair value of the note at moneyness of 80.0 for 161 time steps and LR model is: $977.9350
# The estimated fair value of the note at moneyness of 80.0 for 164 time steps and LR model is: $984.4207
# The estimated fair value of the note at moneyness of 80.0 for 167 time steps and LR model is: $978.8084
# The estimated fair value of the note at moneyness of 80.0 for 170 time steps and LR model is: $983.8704
# The estimated fair value of the note at moneyness of 80.0 for 173 time steps and LR model is: $978.8775
# The estimated fair value of the note at moneyness of 80.0 for 176 time steps and LR model is: $983.8248
# The estimated fair value of the note at moneyness of 80.0 for 179 time steps and LR model is: $977.6529
# The estimated fair value of the note at moneyness of 80.0 for 182 time steps and LR model is: $983.3806
# The estimated fair value of the note at moneyness of 80.0 for 185 time steps and LR model is: $977.7549
# The estimated fair value of the note at moneyness of 80.0 for 188 time steps and LR model is: $984.0701
# The estimated fair value of the note at moneyness of 80.0 for 191 time steps and LR model is: $979.0414
# The estimated fair value of the note at moneyness of 80.0 for 194 time steps and LR model is: $983.1769
# The estimated fair value of the note at moneyness of 80.0 for 197 time steps and LR model is: $978.3526
# The estimated fair value of the note at moneyness of 80.0 for 200 time steps and LR model is: $984.7800
# The estimated fair value of the note at moneyness of 80.0 for 203 time steps and LR model is: $979.1771
# The estimated fair value of the note at moneyness of 80.0 for 206 time steps and LR model is: $984.4676
# The estimated fair value of the note at moneyness of 80.0 for 209 time steps and LR model is: $978.8160
# The estimated fair value of the note at moneyness of 80.0 for 212 time steps and LR model is: $983.9208
# The estimated fair value of the note at moneyness of 80.0 for 215 time steps and LR model is: $978.8527
# The estimated fair value of the note at moneyness of 80.0 for 218 time steps and LR model is: $983.8845
# The estimated fair value of the note at moneyness of 80.0 for 221 time steps and LR model is: $979.6275
# The estimated fair value of the note at moneyness of 80.0 for 224 time steps and LR model is: $983.6898
# The estimated fair value of the note at moneyness of 80.0 for 227 time steps and LR model is: $978.7443
# The estimated fair value of the note at moneyness of 80.0 for 230 time steps and LR model is: $984.0326
# The estimated fair value of the note at moneyness of 80.0 for 233 time steps and LR model is: $978.4456
# The estimated fair value of the note at moneyness of 80.0 for 236 time steps and LR model is: $982.8133
# The estimated fair value of the note at moneyness of 80.0 for 239 time steps and LR model is: $978.4027
# The estimated fair value of the note at moneyness of 80.0 for 242 time steps and LR model is: $983.1920
# The estimated fair value of the note at moneyness of 80.0 for 245 time steps and LR model is: $978.4609
# The estimated fair value of the note at moneyness of 80.0 for 248 time steps and LR model is: $983.4680
# The estimated fair value of the note at moneyness of 80.0 for 251 time steps and LR model is: $979.2952
# The estimated fair value of the note at moneyness of 80.0 for 254 time steps and LR model is: $982.7898
# The estimated fair value of the note at moneyness of 80.0 for 257 time steps and LR model is: $978.0768
# The estimated fair value of the note at moneyness of 80.0 for 260 time steps and LR model is: $982.8065
# The estimated fair value of the note at moneyness of 80.0 for 263 time steps and LR model is: $978.2689
# The estimated fair value of the note at moneyness of 80.0 for 266 time steps and LR model is: $982.7092
# The estimated fair value of the note at moneyness of 80.0 for 269 time steps and LR model is: $978.3641
# The estimated fair value of the note at moneyness of 80.0 for 272 time steps and LR model is: $983.0176
# The estimated fair value of the note at moneyness of 80.0 for 275 time steps and LR model is: $978.6124
# The estimated fair value of the note at moneyness of 80.0 for 278 time steps and LR model is: $983.1191
# The estimated fair value of the note at moneyness of 80.0 for 281 time steps and LR model is: $977.9739
# The estimated fair value of the note at moneyness of 80.0 for 284 time steps and LR model is: $982.5341
# The estimated fair value of the note at moneyness of 80.0 for 287 time steps and LR model is: $978.8246
# The estimated fair value of the note at moneyness of 80.0 for 290 time steps and LR model is: $982.8910
# The estimated fair value of the note at moneyness of 80.0 for 293 time steps and LR model is: $978.3935
# The estimated fair value of the note at moneyness of 80.0 for 296 time steps and LR model is: $982.9631
# The estimated fair value of the note at moneyness of 80.0 for 299 time steps and LR model is: $978.8745
# The estimated fair value of the note at moneyness of 80.0 for 302 time steps and LR model is: $982.6923
# The estimated fair value of the note at moneyness of 80.0 for 305 time steps and LR model is: $977.7554
# The estimated fair value of the note at moneyness of 80.0 for 308 time steps and LR model is: $982.6936
# The estimated fair value of the note at moneyness of 80.0 for 311 time steps and LR model is: $978.4602
# The estimated fair value of the note at moneyness of 80.0 for 314 time steps and LR model is: $982.8705
# The estimated fair value of the note at moneyness of 80.0 for 317 time steps and LR model is: $978.6788
# The estimated fair value of the note at moneyness of 80.0 for 320 time steps and LR model is: $982.3501
# The estimated fair value of the note at moneyness of 80.0 for 323 time steps and LR model is: $977.9283
# The estimated fair value of the note at moneyness of 80.0 for 326 time steps and LR model is: $982.3890
# The estimated fair value of the note at moneyness of 80.0 for 329 time steps and LR model is: $978.8914
# The estimated fair value of the note at moneyness of 80.0 for 332 time steps and LR model is: $982.3358
# The estimated fair value of the note at moneyness of 80.0 for 335 time steps and LR model is: $978.1677
# The estimated fair value of the note at moneyness of 80.0 for 338 time steps and LR model is: $983.0635
# The estimated fair value of the note at moneyness of 80.0 for 341 time steps and LR model is: $978.5060
# The estimated fair value of the note at moneyness of 80.0 for 344 time steps and LR model is: $982.0006
# The estimated fair value of the note at moneyness of 80.0 for 347 time steps and LR model is: $978.3621
# The estimated fair value of the note at moneyness of 80.0 for 350 time steps and LR model is: $982.0909
# The estimated fair value of the note at moneyness of 80.0 for 353 time steps and LR model is: $978.6710
# The estimated fair value of the note at moneyness of 80.0 for 356 time steps and LR model is: $982.1160
# The estimated fair value of the note at moneyness of 80.0 for 359 time steps and LR model is: $978.5283
# The estimated fair value of the note at moneyness of 80.0 for 362 time steps and LR model is: $982.7310
# The estimated fair value of the note at moneyness of 80.0 for 365 time steps and LR model is: $978.6686
# The estimated fair value of the note at moneyness of 80.0 for 368 time steps and LR model is: $982.2089
# The estimated fair value of the note at moneyness of 80.0 for 371 time steps and LR model is: $978.3133
# The estimated fair value of the note at moneyness of 80.0 for 374 time steps and LR model is: $982.3102
# The estimated fair value of the note at moneyness of 80.0 for 377 time steps and LR model is: $978.9460
# The estimated fair value of the note at moneyness of 80.0 for 380 time steps and LR model is: $982.6316
# The estimated fair value of the note at moneyness of 80.0 for 383 time steps and LR model is: $978.2712
# The estimated fair value of the note at moneyness of 80.0 for 386 time steps and LR model is: $982.1442
# The estimated fair value of the note at moneyness of 80.0 for 389 time steps and LR model is: $978.2157
# The estimated fair value of the note at moneyness of 80.0 for 392 time steps and LR model is: $981.8854
# The estimated fair value of the note at moneyness of 80.0 for 395 time steps and LR model is: $978.0939
# The estimated fair value of the note at moneyness of 80.0 for 398 time steps and LR model is: $981.9724
# The estimated fair value of the note at moneyness of 80.0 for 401 time steps and LR model is: $978.2033
# The estimated fair value of the note at moneyness of 80.0 for 404 time steps and LR model is: $982.3558
# The estimated fair value of the note at moneyness of 80.0 for 407 time steps and LR model is: $978.2946
# The estimated fair value of the note at moneyness of 80.0 for 410 time steps and LR model is: $981.4106
# The estimated fair value of the note at moneyness of 80.0 for 413 time steps and LR model is: $978.8692
# The estimated fair value of the note at moneyness of 80.0 for 416 time steps and LR model is: $981.9941
# The estimated fair value of the note at moneyness of 80.0 for 419 time steps and LR model is: $978.4754
# The estimated fair value of the note at moneyness of 80.0 for 422 time steps and LR model is: $982.0230
# The estimated fair value of the note at moneyness of 80.0 for 425 time steps and LR model is: $978.8052
# The estimated fair value of the note at moneyness of 80.0 for 428 time steps and LR model is: $982.1923
# The estimated fair value of the note at moneyness of 80.0 for 431 time steps and LR model is: $978.7083
# The estimated fair value of the note at moneyness of 80.0 for 434 time steps and LR model is: $981.2787
# The estimated fair value of the note at moneyness of 80.0 for 437 time steps and LR model is: $978.2882
# The estimated fair value of the note at moneyness of 80.0 for 440 time steps and LR model is: $981.7251
# The estimated fair value of the note at moneyness of 80.0 for 443 time steps and LR model is: $977.8828
# The estimated fair value of the note at moneyness of 80.0 for 446 time steps and LR model is: $981.8028
# The estimated fair value of the note at moneyness of 80.0 for 449 time steps and LR model is: $978.3958
# The estimated fair value of the note at moneyness of 80.0 for 452 time steps and LR model is: $982.4136
# The estimated fair value of the note at moneyness of 80.0 for 455 time steps and LR model is: $979.0949
# The estimated fair value of the note at moneyness of 80.0 for 458 time steps and LR model is: $982.7202
# The estimated fair value of the note at moneyness of 80.0 for 461 time steps and LR model is: $979.1872
# The estimated fair value of the note at moneyness of 80.0 for 464 time steps and LR model is: $982.0210
# The estimated fair value of the note at moneyness of 80.0 for 467 time steps and LR model is: $978.9451
# The estimated fair value of the note at moneyness of 80.0 for 470 time steps and LR model is: $982.0902
# The estimated fair value of the note at moneyness of 80.0 for 473 time steps and LR model is: $978.1338
# The estimated fair value of the note at moneyness of 80.0 for 476 time steps and LR model is: $981.6987
# The estimated fair value of the note at moneyness of 80.0 for 479 time steps and LR model is: $978.4965
# The estimated fair value of the note at moneyness of 80.0 for 482 time steps and LR model is: $982.0041
# The estimated fair value of the note at moneyness of 80.0 for 485 time steps and LR model is: $978.1651
# The estimated fair value of the note at moneyness of 80.0 for 488 time steps and LR model is: $981.6753
# The estimated fair value of the note at moneyness of 80.0 for 491 time steps and LR model is: $979.1105
# The estimated fair value of the note at moneyness of 80.0 for 494 time steps and LR model is: $981.5749
# The estimated fair value of the note at moneyness of 80.0 for 497 time steps and LR model is: $978.5105
# The estimated fair value of the note at moneyness of 80.0 for 500 time steps and LR model is: $981.4305
# The estimated fair value of the note at moneyness of 80.0 for 503 time steps and LR model is: $978.3977
# The estimated fair value of the note at moneyness of 80.0 for 506 time steps and LR model is: $982.2624
# The estimated fair value of the note at moneyness of 80.0 for 509 time steps and LR model is: $978.7093
# The estimated fair value of the note at moneyness of 80.0 for 512 time steps and LR model is: $981.6799
# The estimated fair value of the note at moneyness of 80.0 for 515 time steps and LR model is: $978.5472
# The estimated fair value of the note at moneyness of 80.0 for 518 time steps and LR model is: $981.5881
# The estimated fair value of the note at moneyness of 80.0 for 521 time steps and LR model is: $978.3877
# The estimated fair value of the note at moneyness of 80.0 for 524 time steps and LR model is: $981.4539
# The estimated fair value of the note at moneyness of 80.0 for 527 time steps and LR model is: $978.4637
# The estimated fair value of the note at moneyness of 80.0 for 530 time steps and LR model is: $981.5189
# The estimated fair value of the note at moneyness of 80.0 for 533 time steps and LR model is: $978.6047
# The estimated fair value of the note at moneyness of 80.0 for 536 time steps and LR model is: $981.5776
# The estimated fair value of the note at moneyness of 80.0 for 539 time steps and LR model is: $978.5678
# The estimated fair value of the note at moneyness of 80.0 for 542 time steps and LR model is: $981.4072
# The estimated fair value of the note at moneyness of 80.0 for 545 time steps and LR model is: $978.3981
# The estimated fair value of the note at moneyness of 80.0 for 548 time steps and LR model is: $981.7205
# The estimated fair value of the note at moneyness of 80.0 for 551 time steps and LR model is: $978.1025
# The estimated fair value of the note at moneyness of 80.0 for 554 time steps and LR model is: $981.3831
# The estimated fair value of the note at moneyness of 80.0 for 557 time steps and LR model is: $978.5788
# The estimated fair value of the note at moneyness of 80.0 for 560 time steps and LR model is: $981.6515
# The estimated fair value of the note at moneyness of 80.0 for 563 time steps and LR model is: $977.8087
# The estimated fair value of the note at moneyness of 80.0 for 566 time steps and LR model is: $981.3347
# The estimated fair value of the note at moneyness of 80.0 for 569 time steps and LR model is: $978.7588
# The estimated fair value of the note at moneyness of 80.0 for 572 time steps and LR model is: $981.5818
# The estimated fair value of the note at moneyness of 80.0 for 575 time steps and LR model is: $978.6465
# The estimated fair value of the note at moneyness of 80.0 for 578 time steps and LR model is: $981.8239
# The estimated fair value of the note at moneyness of 80.0 for 581 time steps and LR model is: $978.5093
# The estimated fair value of the note at moneyness of 80.0 for 584 time steps and LR model is: $981.9339
# The estimated fair value of the note at moneyness of 80.0 for 587 time steps and LR model is: $978.1983
# The estimated fair value of the note at moneyness of 80.0 for 590 time steps and LR model is: $980.7780
# The estimated fair value of the note at moneyness of 80.0 for 593 time steps and LR model is: $978.2130
# The estimated fair value of the note at moneyness of 80.0 for 596 time steps and LR model is: $981.0896
# The estimated fair value of the note at moneyness of 80.0 for 599 time steps and LR model is: $978.1058
# The estimated fair value of the note at moneyness of 80.0 for 602 time steps and LR model is: $980.9922
# The estimated fair value of the note at moneyness of 80.0 for 605 time steps and LR model is: $978.4336
# The estimated fair value of the note at moneyness of 80.0 for 608 time steps and LR model is: $981.3028
# The estimated fair value of the note at moneyness of 80.0 for 611 time steps and LR model is: $978.1212
# The estimated fair value of the note at moneyness of 80.0 for 614 time steps and LR model is: $981.5500
# The estimated fair value of the note at moneyness of 80.0 for 617 time steps and LR model is: $978.6662
# The estimated fair value of the note at moneyness of 80.0 for 620 time steps and LR model is: $981.5503
# The estimated fair value of the note at moneyness of 80.0 for 623 time steps and LR model is: $978.3395
# The estimated fair value of the note at moneyness of 80.0 for 626 time steps and LR model is: $981.6402
# The estimated fair value of the note at moneyness of 80.0 for 629 time steps and LR model is: $978.2098
# The estimated fair value of the note at moneyness of 80.0 for 632 time steps and LR model is: $981.1683
# The estimated fair value of the note at moneyness of 80.0 for 635 time steps and LR model is: $978.7251
# The estimated fair value of the note at moneyness of 80.0 for 638 time steps and LR model is: $981.4634
# The estimated fair value of the note at moneyness of 80.0 for 641 time steps and LR model is: $978.1934
# The estimated fair value of the note at moneyness of 80.0 for 644 time steps and LR model is: $981.4196
# The estimated fair value of the note at moneyness of 80.0 for 647 time steps and LR model is: $978.2743
# The estimated fair value of the note at moneyness of 80.0 for 650 time steps and LR model is: $981.1190
# The estimated fair value of the note at moneyness of 80.0 for 653 time steps and LR model is: $978.1734
# The estimated fair value of the note at moneyness of 80.0 for 656 time steps and LR model is: $981.0264
# The estimated fair value of the note at moneyness of 80.0 for 659 time steps and LR model is: $978.2870
# The estimated fair value of the note at moneyness of 80.0 for 662 time steps and LR model is: $981.1374
# The estimated fair value of the note at moneyness of 80.0 for 665 time steps and LR model is: $978.5165
# The estimated fair value of the note at moneyness of 80.0 for 668 time steps and LR model is: $981.0266
# The estimated fair value of the note at moneyness of 80.0 for 671 time steps and LR model is: $978.2111
# The estimated fair value of the note at moneyness of 80.0 for 674 time steps and LR model is: $981.1058
# The estimated fair value of the note at moneyness of 80.0 for 677 time steps and LR model is: $977.9445
# The estimated fair value of the note at moneyness of 80.0 for 680 time steps and LR model is: $980.7861
# The estimated fair value of the note at moneyness of 80.0 for 683 time steps and LR model is: $978.6301
# The estimated fair value of the note at moneyness of 80.0 for 686 time steps and LR model is: $981.2828
# The estimated fair value of the note at moneyness of 80.0 for 689 time steps and LR model is: $978.1802
# The estimated fair value of the note at moneyness of 80.0 for 692 time steps and LR model is: $981.3307
# The estimated fair value of the note at moneyness of 80.0 for 695 time steps and LR model is: $978.4178
# The estimated fair value of the note at moneyness of 80.0 for 698 time steps and LR model is: $981.0171
# The estimated fair value of the note at moneyness of 80.0 for 701 time steps and LR model is: $978.3494
# The estimated fair value of the note at moneyness of 80.0 for 704 time steps and LR model is: $981.4617
# The estimated fair value of the note at moneyness of 80.0 for 707 time steps and LR model is: $978.2674
# The estimated fair value of the note at moneyness of 80.0 for 710 time steps and LR model is: $981.1814
# The estimated fair value of the note at moneyness of 80.0 for 713 time steps and LR model is: $978.8531
# The estimated fair value of the note at moneyness of 80.0 for 716 time steps and LR model is: $981.2202
# The estimated fair value of the note at moneyness of 80.0 for 719 time steps and LR model is: $978.0033
# The estimated fair value of the note at moneyness of 80.0 for 722 time steps and LR model is: $980.9239
# The estimated fair value of the note at moneyness of 80.0 for 725 time steps and LR model is: $978.2949
# The estimated fair value of the note at moneyness of 80.0 for 728 time steps and LR model is: $980.9760
# The estimated fair value of the note at moneyness of 80.0 for 731 time steps and LR model is: $978.2064
# The estimated fair value of the note at moneyness of 80.0 for 734 time steps and LR model is: $981.2913
# The estimated fair value of the note at moneyness of 80.0 for 737 time steps and LR model is: $978.1324
# The estimated fair value of the note at moneyness of 80.0 for 740 time steps and LR model is: $980.9759
# The estimated fair value of the note at moneyness of 80.0 for 743 time steps and LR model is: $978.3436
# The estimated fair value of the note at moneyness of 80.0 for 746 time steps and LR model is: $980.9457
# The estimated fair value of the note at moneyness of 80.0 for 749 time steps and LR model is: $978.6191
# The estimated fair value of the note at moneyness of 80.0 for 752 time steps and LR model is: $981.0162
# The estimated fair value of the note at moneyness of 80.0 for 755 time steps and LR model is: $978.6881
# The estimated fair value of the note at moneyness of 80.0 for 758 time steps and LR model is: $981.2879
# The estimated fair value of the note at moneyness of 80.0 for 761 time steps and LR model is: $978.6296
# The estimated fair value of the note at moneyness of 80.0 for 764 time steps and LR model is: $980.6192
# The estimated fair value of the note at moneyness of 80.0 for 767 time steps and LR model is: $977.9966
# The estimated fair value of the note at moneyness of 80.0 for 770 time steps and LR model is: $980.8301
# The estimated fair value of the note at moneyness of 80.0 for 773 time steps and LR model is: $977.9351
# The estimated fair value of the note at moneyness of 80.0 for 776 time steps and LR model is: $980.9269
# The estimated fair value of the note at moneyness of 80.0 for 779 time steps and LR model is: $978.1785
# The estimated fair value of the note at moneyness of 80.0 for 782 time steps and LR model is: $980.8134
# The estimated fair value of the note at moneyness of 80.0 for 785 time steps and LR model is: $978.2645
# The estimated fair value of the note at moneyness of 80.0 for 788 time steps and LR model is: $980.5394
# The estimated fair value of the note at moneyness of 80.0 for 791 time steps and LR model is: $977.9876
# The estimated fair value of the note at moneyness of 80.0 for 794 time steps and LR model is: $981.1135
# The estimated fair value of the note at moneyness of 80.0 for 797 time steps and LR model is: $978.2651
# The estimated fair value of the note at moneyness of 80.0 for 800 time steps and LR model is: $981.2161
# The estimated fair value of the note at moneyness of 80.0 for 803 time steps and LR model is: $978.4097
# The estimated fair value of the note at moneyness of 80.0 for 806 time steps and LR model is: $981.2618
# The estimated fair value of the note at moneyness of 80.0 for 809 time steps and LR model is: $978.2648
# The estimated fair value of the note at moneyness of 80.0 for 812 time steps and LR model is: $981.3746
# The estimated fair value of the note at moneyness of 80.0 for 815 time steps and LR model is: $978.7229
# The estimated fair value of the note at moneyness of 80.0 for 818 time steps and LR model is: $981.3215
# The estimated fair value of the note at moneyness of 80.0 for 821 time steps and LR model is: $978.7619
# The estimated fair value of the note at moneyness of 80.0 for 824 time steps and LR model is: $981.2074
# The estimated fair value of the note at moneyness of 80.0 for 827 time steps and LR model is: $978.8542
# The estimated fair value of the note at moneyness of 80.0 for 830 time steps and LR model is: $980.9332
# The estimated fair value of the note at moneyness of 80.0 for 833 time steps and LR model is: $978.5828
# The estimated fair value of the note at moneyness of 80.0 for 836 time steps and LR model is: $981.3655
# The estimated fair value of the note at moneyness of 80.0 for 839 time steps and LR model is: $978.6780
# The estimated fair value of the note at moneyness of 80.0 for 842 time steps and LR model is: $980.8887
# The estimated fair value of the note at moneyness of 80.0 for 845 time steps and LR model is: $978.4536
# The estimated fair value of the note at moneyness of 80.0 for 848 time steps and LR model is: $980.8042
# The estimated fair value of the note at moneyness of 80.0 for 851 time steps and LR model is: $978.1878
# The estimated fair value of the note at moneyness of 80.0 for 854 time steps and LR model is: $980.8603
# The estimated fair value of the note at moneyness of 80.0 for 857 time steps and LR model is: $978.1245
# The estimated fair value of the note at moneyness of 80.0 for 860 time steps and LR model is: $980.9796
# The estimated fair value of the note at moneyness of 80.0 for 863 time steps and LR model is: $978.3814
# The estimated fair value of the note at moneyness of 80.0 for 866 time steps and LR model is: $980.8892
# The estimated fair value of the note at moneyness of 80.0 for 869 time steps and LR model is: $978.4328
# The estimated fair value of the note at moneyness of 80.0 for 872 time steps and LR model is: $980.8002
# The estimated fair value of the note at moneyness of 80.0 for 875 time steps and LR model is: $978.5193
# The estimated fair value of the note at moneyness of 80.0 for 878 time steps and LR model is: $980.7972
# The estimated fair value of the note at moneyness of 80.0 for 881 time steps and LR model is: $978.2407
# The estimated fair value of the note at moneyness of 80.0 for 884 time steps and LR model is: $981.2491
# The estimated fair value of the note at moneyness of 80.0 for 887 time steps and LR model is: $978.5200
# The estimated fair value of the note at moneyness of 80.0 for 890 time steps and LR model is: $980.8528
# The estimated fair value of the note at moneyness of 80.0 for 893 time steps and LR model is: $978.3722
# The estimated fair value of the note at moneyness of 80.0 for 896 time steps and LR model is: $980.7076
# The estimated fair value of the note at moneyness of 80.0 for 899 time steps and LR model is: $978.1072
# The estimated fair value of the note at moneyness of 80.0 for 902 time steps and LR model is: $980.7987
# The estimated fair value of the note at moneyness of 80.0 for 905 time steps and LR model is: $978.5425
# The estimated fair value of the note at moneyness of 80.0 for 908 time steps and LR model is: $980.5667
# The estimated fair value of the note at moneyness of 80.0 for 911 time steps and LR model is: $978.4707
# The estimated fair value of the note at moneyness of 80.0 for 914 time steps and LR model is: $980.8324
# The estimated fair value of the note at moneyness of 80.0 for 917 time steps and LR model is: $978.2245
# The estimated fair value of the note at moneyness of 80.0 for 920 time steps and LR model is: $980.6831
# The estimated fair value of the note at moneyness of 80.0 for 923 time steps and LR model is: $978.1885
# The estimated fair value of the note at moneyness of 80.0 for 926 time steps and LR model is: $980.7851
# The estimated fair value of the note at moneyness of 80.0 for 929 time steps and LR model is: $978.2988
# The estimated fair value of the note at moneyness of 80.0 for 932 time steps and LR model is: $980.8691
# The estimated fair value of the note at moneyness of 80.0 for 935 time steps and LR model is: $978.3926
# The estimated fair value of the note at moneyness of 80.0 for 938 time steps and LR model is: $980.8142
# The estimated fair value of the note at moneyness of 80.0 for 941 time steps and LR model is: $978.3098
# The estimated fair value of the note at moneyness of 80.0 for 944 time steps and LR model is: $980.6979
# The estimated fair value of the note at moneyness of 80.0 for 947 time steps and LR model is: $978.3080
# The estimated fair value of the note at moneyness of 80.0 for 950 time steps and LR model is: $980.7860
# The estimated fair value of the note at moneyness of 80.0 for 953 time steps and LR model is: $978.7402
# The estimated fair value of the note at moneyness of 80.0 for 956 time steps and LR model is: $980.6891
# The estimated fair value of the note at moneyness of 80.0 for 959 time steps and LR model is: $978.3830
# The estimated fair value of the note at moneyness of 80.0 for 962 time steps and LR model is: $981.2184
# The estimated fair value of the note at moneyness of 80.0 for 965 time steps and LR model is: $978.2835
# The estimated fair value of the note at moneyness of 80.0 for 968 time steps and LR model is: $980.3241
# The estimated fair value of the note at moneyness of 80.0 for 971 time steps and LR model is: $978.2920
# The estimated fair value of the note at moneyness of 80.0 for 974 time steps and LR model is: $980.6018
# The estimated fair value of the note at moneyness of 80.0 for 977 time steps and LR model is: $978.3971
# The estimated fair value of the note at moneyness of 80.0 for 980 time steps and LR model is: $980.5348
# The estimated fair value of the note at moneyness of 80.0 for 983 time steps and LR model is: $978.3448
# The estimated fair value of the note at moneyness of 80.0 for 986 time steps and LR model is: $980.5899
# The estimated fair value of the note at moneyness of 80.0 for 989 time steps and LR model is: $978.1029
# The estimated fair value of the note at moneyness of 80.0 for 992 time steps and LR model is: $980.3332
# The estimated fair value of the note at moneyness of 80.0 for 995 time steps and LR model is: $978.0440
# The estimated fair value of the note at moneyness of 80.0 for 998 time steps and LR model is: $980.5619

# %%
df_lr = pd.DataFrame({
    'N': N_values,
    'Note_Value': LR_values
})
# Add better column names and reset index if needed
df_lr = df_lr.reset_index(drop=True)
df_lr.head()
# Out:
#     N  Note_Value
# 0  50  992.067213
# 1  53  981.153977
# 2  56  989.339922
# 3  59  979.943634
# 4  62  989.156642

# %%
# plotting the error results
plt.figure(figsize=(20, 10))
plt.plot(df_lr['N'],df_lr['Note_Value'], label='Leisen-Reimer (1996)')
plt.xlabel('Number of time steps (N)')
plt.ylabel('LR Note Value')
plt.title('LR Note Value vs. Number of Time Steps')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-bottom: 2px solid black; display: inline-block; text-align: center; margin: 20px;">
# <span style="font-family: Cambria, serif; font-weight: bold; font-size: 28px;">End of Project 1</span>
# </div>

# %% [markdown]
# ---
